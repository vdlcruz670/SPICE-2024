# %% [markdown]
# <a href="https://colab.research.google.com/github/vdlcruz670/SPICE-2024/blob/main/waveheight_collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Wave Height Predictions with ARIMA

# %% [markdown]
# ## Introduction

# %% [markdown]
# The goal is to use machine learning to build a time-series model that can be used to predict wave height measurements for the selected buoy area. We'll be building an ARIMA model.
#
# The dataset comes from the [National Data Buoy Center](https://www.ndbc.noaa.gov/).
#
# The buoy used for this example is Buoy #[51101](https://www.ndbc.noaa.gov/station_page.php?station=51101), which is located Northwest of Kauai, Hawaii.

# %% [markdown]
# ### ARIMA
#
# You can read this article for more info.
# https://medium.com/analytics-vidhya/arima-for-dummies-ba761d59a051

# %% [markdown]
# # Imports and Data

# %% [markdown]
# ## Imports
#
# The below code chunk loads in all your packages and imports, make sure to run this every time you start your session.
#
# Packages include all the tools you need to successfully run all your code and analysis.

# %%
# !pip install statsmodels
# !pip install pmdarima

from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

from sklearn import linear_model

from pandas import to_datetime
import datetime
from datetime import datetime
import pandas as pd
import pmdarima as pm
import itertools
import warnings
import matplotlib.pyplot as plt
from matplotlib import pyplot

from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_predict

warnings.filterwarnings('ignore')
import seaborn as sns

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.25.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.11.4)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (2.0.3)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (3.0.10)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.25.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.0.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.11.4)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.0.7)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (67.7.2)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.4

# %% [markdown]
# ## Data
#
# To load in our data, we use the pandas function read_csv to get the data directly from the National Data Buoy Center and are assigning it to the variable called *df1*.
#
# A variable is a place/object where we can store information.

# %%
df1 = pd.read_csv('https://www.ndbc.noaa.gov/view_text_file.php?filename=51101h2017.txt.gz&dir=data/historical/stdmet/', delimiter= '\s+', index_col=False) # reading in the data

# %%
df_23 = pd.read_csv('https://www.ndbc.noaa.gov/view_text_file.php?filename=51101h2023.txt.gz&dir=data/historical/stdmet/', delimiter= '\s+', index_col=False) # reading in the data
df_22 = pd.read_csv('https://www.ndbc.noaa.gov/view_text_file.php?filename=51101h2022.txt.gz&dir=data/historical/stdmet/', delimiter= '\s+', index_col=False) # reading in the data
df_21 = pd.read_csv('https://www.ndbc.noaa.gov/view_text_file.php?filename=51101h2021.txt.gz&dir=data/historical/stdmet/', delimiter= '\s+', index_col=False) # reading in the data
df_20 = pd.read_csv('https://www.ndbc.noaa.gov/view_text_file.php?filename=51101h2020.txt.gz&dir=data/historical/stdmet/', delimiter= '\s+', index_col=False) # reading in the data
df_19 = pd.read_csv('https://www.ndbc.noaa.gov/view_text_file.php?filename=51101h2019.txt.gz&dir=data/historical/stdmet/', delimiter= '\s+', index_col=False) # reading in the data

# %%
df1.head() # looking at first 5 rows
# Out:
#     #YY  MM  DD  hh  mm  WDIR WSPD  GST   WVHT    DPD    APD   MWD    PRES  \
# 0   #yr  mo  dy  hr  mn  degT  m/s  m/s      m    sec    sec  degT     hPa
# 1  2023  01  01  00  00   191  4.1  5.4  99.00  99.00  99.00   999  1016.4
# 2  2023  01  01  00  10   188  4.0  5.3   2.11  12.90   9.09   302  1016.4
# 3  2023  01  01  00  20   191  3.6  4.8  99.00  99.00  99.00   999  1016.4
# 4  2023  01  01  00  30   195  4.0  5.2  99.00  99.00  99.00   999  1016.2
#
#    ATMP  WTMP   DEWP   VIS   TIDE
# 0  degC  degC   degC    mi     ft
# 1  24.1  24.3  999.0  99.0  99.00
# 2  24.1  24.3  999.0  99.0  99.00
# 3  24.1  24.3  999.0  99.0  99.00
# 4  24.1  24.4  999.0  99.0  99.00

# %% [markdown]
# # Exploring the Data
#
# For this project, the target variable we'll focus on is WVHT (wave height in meters).

# %%
df1.info() # looking at basic information about your variable
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8645 entries, 0 to 8644
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   #YY     8645 non-null   object
#  1   MM      8645 non-null   object
#  2   DD      8645 non-null   object
#  3   hh      8645 non-null   object
#  4   mm      8645 non-null   object
#  5   WDIR    8645 non-null   object
#  6   WSPD    8645 non-null   object
#  7   GST     8645 non-null   object
#  8   WVHT    8645 non-null   object
#  9   DPD     8645 non-null   object
#  10  APD     8645 non-null   object
#  11  MWD     8645 non-null   object
#  12  PRES    8645 non-null   object
#  13  ATMP    8645 non-null   object
#  14  WTMP    8645 non-null   object
#  15  DEWP    8645 non-null   object
#  16  VIS     8645 non-null   object
#  17  TIDE    8645 non-null   object
# dtypes: object(18)
# memory usage: 1.2+ MB

# %% [markdown]
# From the above information, we learn that the dataset currently has 8,645 rows and 18 columns.

# %%
df1.head() # looking at the first five rows of your data
# Out:
#     #YY  MM  DD  hh  mm  WDIR WSPD  GST  WVHT    DPD   APD   MWD    PRES  \
# 0   #yr  mo  dy  hr  mn  degT  m/s  m/s     m    sec   sec  degT     hPa
# 1  2016  12  31  23  50    52  5.3  7.5  1.93   9.09  6.53    50  1016.1
# 2  2017  01  01  00  50    52  4.6  6.4  1.97  10.00  6.52    57  1016.0
# 3  2017  01  01  01  50    31  6.8  8.5  2.02  10.00  6.52    52  1016.2
# 4  2017  01  01  02  50    32  6.2  8.7  2.08   9.09  6.77    48  1016.6
#
#    ATMP  WTMP   DEWP   VIS   TIDE
# 0  degC  degC   degC    mi     ft
# 1  21.2  24.5  999.0  99.0  99.00
# 2  21.3  24.5  999.0  99.0  99.00
# 3  21.3  24.5  999.0  99.0  99.00
# 4  21.4  24.5  999.0  99.0  99.00

# %%
df1.tail() # looking at the last five rows of your data
# Out:
#        #YY  MM  DD  hh  mm WDIR WSPD  GST  WVHT    DPD   APD  MWD    PRES  \
# 8640  2017  12  31  18  50  114  5.9  7.0  1.39  13.79  6.72  316  1020.8
# 8641  2017  12  31  19  50  114  4.3  5.4  1.54  14.81  6.85  300  1021.3
# 8642  2017  12  31  20  50  132  5.3  6.9  1.60  14.81  7.17  323  1021.0
# 8643  2017  12  31  21  50  116  5.4  7.2  1.53  13.79  6.81  310  1020.5
# 8644  2017  12  31  22  50  134  5.6  7.1  1.59  13.79  6.74  320  1019.4
#
#       ATMP  WTMP   DEWP   VIS   TIDE
# 8640  22.2  23.4  999.0  99.0  99.00
# 8641  22.6  23.4  999.0  99.0  99.00
# 8642  22.6  23.5  999.0  99.0  99.00
# 8643  22.6  23.5  999.0  99.0  99.00
# 8644  22.7  23.6  999.0  99.0  99.00

# %% [markdown]
# Let's look to see if we have NA values (missing values) in our dataset.
#
# We're making another variable called *na_values*, to see if any column has NA values.

# %%
na_values = pd.DataFrame(df_21.isna().sum()) # looking at na values
na_values # typing in the variable name prints it out for you
# Out:
#       0
# #YY   0
# MM    0
# DD    0
# hh    0
# mm    0
# WDIR  0
# WSPD  0
# GST   0
# WVHT  0
# DPD   0
# APD   0
# MWD   0
# PRES  0
# ATMP  0
# WTMP  0
# DEWP  0
# VIS   0
# TIDE  0

# %%
print(len(df_23)) # checking how many rows the variable has
print(len(df_22))
print(len(df_21))
print(len(df_20))
print(len(df_19))
# Out:
# 52523
# 52480
# 51485
# 52178
# 52123

# %%
df_22
# Out:
#         #YY  MM  DD  hh  mm  WDIR  WSPD   GST   WVHT    DPD    APD   MWD  \
# 0       #yr  mo  dy  hr  mn  degT   m/s   m/s      m    sec    sec  degT
# 1      2022  01  01  00  00   112   9.4  12.1  99.00  99.00  99.00   999
# 2      2022  01  01  00  10   110   8.6  10.8  99.00  99.00  99.00   999
# 3      2022  01  01  00  20   115   9.8  13.1  99.00  99.00  99.00   999
# 4      2022  01  01  00  30   108  10.3  12.6  99.00  99.00  99.00   999
# ...     ...  ..  ..  ..  ..   ...   ...   ...    ...    ...    ...   ...
# 52475  2022  12  31  23  10   197   4.0   5.1   2.27   12.9   8.93   296
# 52476  2022  12  31  23  20   198   4.1   5.0   99.0   99.0   99.0   999
# 52477  2022  12  31  23  30   195   3.9   5.4   99.0   99.0   99.0   999
# 52478  2022  12  31  23  40   192   4.0   5.5   2.23  12.12   8.82   303
# 52479  2022  12  31  23  50   193   4.0   5.0   99.0   99.0   99.0   999
#
#          PRES  ATMP  WTMP   DEWP   VIS   TIDE
# 0         hPa  degC  degC   degC    mi     ft
# 1      1004.4  23.4  24.3   22.3  99.0  99.00
# 2      1004.2  23.4  24.3   22.3  99.0  99.00
# 3      1004.0  23.6  24.2   22.4  99.0  99.00
# 4      1003.9  23.5  24.2   22.5  99.0  99.00
# ...       ...   ...   ...    ...   ...    ...
# 52475  1017.4  24.1  24.2  999.0  99.0   99.0
# 52476  1017.1  24.1  24.2  999.0  99.0   99.0
# 52477  1016.9  24.0  24.2  999.0  99.0   99.0
# 52478  1016.7  24.0  24.3  999.0  99.0   99.0
# 52479  1016.5  24.1  24.3  999.0  99.0   99.0
#
# [52480 rows x 18 columns]
# Warning: total number of rows (52480) exceeds max_rows (20000). Limiting to first (20000) rows.

# %% [markdown]
# # Data Cleaning
#
# We need to clean our data to help our analysis run smoother and format it properly.

# %% [markdown]
# We'll be deleting the first two rows of our dataset as it just repeats the column names and has a row from 2016, and assigning it to a new variable called df1_clean.

# %%
df1_clean = df1.iloc[2:] # dropping the first two rows
df1_clean
# Out:
#        #YY  MM  DD  hh  mm WDIR WSPD  GST  WVHT    DPD   APD  MWD    PRES  \
# 2     2017  01  01  00  50   52  4.6  6.4  1.97  10.00  6.52   57  1016.0
# 3     2017  01  01  01  50   31  6.8  8.5  2.02  10.00  6.52   52  1016.2
# 4     2017  01  01  02  50   32  6.2  8.7  2.08   9.09  6.77   48  1016.6
# 5     2017  01  01  03  50   26  5.3  7.0  1.95   9.09  6.48   63  1016.8
# 6     2017  01  01  04  50   39  5.2  7.0  1.69  10.00  6.53   63  1017.0
# ...    ...  ..  ..  ..  ..  ...  ...  ...   ...    ...   ...  ...     ...
# 8640  2017  12  31  18  50  114  5.9  7.0  1.39  13.79  6.72  316  1020.8
# 8641  2017  12  31  19  50  114  4.3  5.4  1.54  14.81  6.85  300  1021.3
# 8642  2017  12  31  20  50  132  5.3  6.9  1.60  14.81  7.17  323  1021.0
# 8643  2017  12  31  21  50  116  5.4  7.2  1.53  13.79  6.81  310  1020.5
# 8644  2017  12  31  22  50  134  5.6  7.1  1.59  13.79  6.74  320  1019.4
#
#       ATMP  WTMP   DEWP   VIS   TIDE
# 2     21.3  24.5  999.0  99.0  99.00
# 3     21.3  24.5  999.0  99.0  99.00
# 4     21.4  24.5  999.0  99.0  99.00
# 5     21.2  24.4  999.0  99.0  99.00
# 6     21.2  24.4  999.0  99.0  99.00
# ...    ...   ...    ...   ...    ...
# 8640  22.2  23.4  999.0  99.0  99.00
# 8641  22.6  23.4  999.0  99.0  99.00
# 8642  22.6  23.5  999.0  99.0  99.00
# 8643  22.6  23.5  999.0  99.0  99.00
# 8644  22.7  23.6  999.0  99.0  99.00
#
# [8643 rows x 18 columns]

# %% [markdown]
# As you can see, there are separate columns for year, month, day, hour, and minute. We need to combine these columns in order to create a single datetime column.

# %%
df1_clean = df1_clean.astype({'#YY' : str, 'MM' : str, 'DD' : str, 'hh' : str, 'mm' : str}) # converting these columns to a string data type
df1_clean['Date'] = df1_clean['#YY'] + '-' + df1_clean['MM'] + '-' + df1_clean['DD'] + ' ' + df1_clean['hh'] + ':' + df1_clean['mm'] # combining all the datetime info into a Date column
df1_clean = df1_clean.drop(columns=['#YY','MM','DD','hh','mm']) # deleting the old date and time columns
df1_clean
# Out:
#      WDIR WSPD  GST  WVHT    DPD   APD  MWD    PRES  ATMP  WTMP   DEWP   VIS  \
# 2      52  4.6  6.4  1.97  10.00  6.52   57  1016.0  21.3  24.5  999.0  99.0
# 3      31  6.8  8.5  2.02  10.00  6.52   52  1016.2  21.3  24.5  999.0  99.0
# 4      32  6.2  8.7  2.08   9.09  6.77   48  1016.6  21.4  24.5  999.0  99.0
# 5      26  5.3  7.0  1.95   9.09  6.48   63  1016.8  21.2  24.4  999.0  99.0
# 6      39  5.2  7.0  1.69  10.00  6.53   63  1017.0  21.2  24.4  999.0  99.0
# ...   ...  ...  ...   ...    ...   ...  ...     ...   ...   ...    ...   ...
# 8640  114  5.9  7.0  1.39  13.79  6.72  316  1020.8  22.2  23.4  999.0  99.0
# 8641  114  4.3  5.4  1.54  14.81  6.85  300  1021.3  22.6  23.4  999.0  99.0
# 8642  132  5.3  6.9  1.60  14.81  7.17  323  1021.0  22.6  23.5  999.0  99.0
# 8643  116  5.4  7.2  1.53  13.79  6.81  310  1020.5  22.6  23.5  999.0  99.0
# 8644  134  5.6  7.1  1.59  13.79  6.74  320  1019.4  22.7  23.6  999.0  99.0
#
#        TIDE              Date
# 2     99.00  2017-01-01 00:50
# 3     99.00  2017-01-01 01:50
# 4     99.00  2017-01-01 02:50
# 5     99.00  2017-01-01 03:50
# 6     99.00  2017-01-01 04:50
# ...     ...               ...
# 8640  99.00  2017-12-31 18:50
# 8641  99.00  2017-12-31 19:50
# 8642  99.00  2017-12-31 20:50
# 8643  99.00  2017-12-31 21:50
# 8644  99.00  2017-12-31 22:50
#
# [8643 rows x 14 columns]

# %% [markdown]
# Now we have one column with all the information we need. To move on, we need the data type for that column to be datetime format.

# %%
df1_clean['Date'] = pd.to_datetime(df1_clean['Date'])
df1_clean
# Out:
#      WDIR WSPD  GST  WVHT    DPD   APD  MWD    PRES  ATMP  WTMP   DEWP   VIS  \
# 2      52  4.6  6.4  1.97  10.00  6.52   57  1016.0  21.3  24.5  999.0  99.0
# 3      31  6.8  8.5  2.02  10.00  6.52   52  1016.2  21.3  24.5  999.0  99.0
# 4      32  6.2  8.7  2.08   9.09  6.77   48  1016.6  21.4  24.5  999.0  99.0
# 5      26  5.3  7.0  1.95   9.09  6.48   63  1016.8  21.2  24.4  999.0  99.0
# 6      39  5.2  7.0  1.69  10.00  6.53   63  1017.0  21.2  24.4  999.0  99.0
# ...   ...  ...  ...   ...    ...   ...  ...     ...   ...   ...    ...   ...
# 8640  114  5.9  7.0  1.39  13.79  6.72  316  1020.8  22.2  23.4  999.0  99.0
# 8641  114  4.3  5.4  1.54  14.81  6.85  300  1021.3  22.6  23.4  999.0  99.0
# 8642  132  5.3  6.9  1.60  14.81  7.17  323  1021.0  22.6  23.5  999.0  99.0
# 8643  116  5.4  7.2  1.53  13.79  6.81  310  1020.5  22.6  23.5  999.0  99.0
# 8644  134  5.6  7.1  1.59  13.79  6.74  320  1019.4  22.7  23.6  999.0  99.0
#
#        TIDE                Date
# 2     99.00 2017-01-01 00:50:00
# 3     99.00 2017-01-01 01:50:00
# 4     99.00 2017-01-01 02:50:00
# 5     99.00 2017-01-01 03:50:00
# 6     99.00 2017-01-01 04:50:00
# ...     ...                 ...
# 8640  99.00 2017-12-31 18:50:00
# 8641  99.00 2017-12-31 19:50:00
# 8642  99.00 2017-12-31 20:50:00
# 8643  99.00 2017-12-31 21:50:00
# 8644  99.00 2017-12-31 22:50:00
#
# [8643 rows x 14 columns]

# %%
df1_clean.info() # looking at updated info about our clean dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8644 entries, 1 to 8644
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   WDIR    8644 non-null   object
#  1   WSPD    8644 non-null   object
#  2   GST     8644 non-null   object
#  3   WVHT    8644 non-null   object
#  4   DPD     8644 non-null   object
#  5   APD     8644 non-null   object
#  6   MWD     8644 non-null   object
#  7   PRES    8644 non-null   object
#  8   ATMP    8644 non-null   object
#  9   WTMP    8644 non-null   object
#  10  DEWP    8644 non-null   object
#  11  VIS     8644 non-null   object
#  12  TIDE    8644 non-null   object
#  13  Date    8644 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(13)
# memory usage: 945.6+ KB

# %% [markdown]
# We see that the date column is a datetime data type, and the dataset is now 8,643 rows and 14 columns.

# %% [markdown]
# # ARIMA

# %% [markdown]
# ## ARIMA Prep
#
# In ARIMA, we're only going to be looking at two columns - the date and the WVHT columns (wave height is what we're trying to predict). We're going to select those two columns only and store it in a new variable called *arima_data*.

# %%
arima_data = df1_clean[['Date', 'WVHT']] # selecting columns
arima_data.head() # looking at first five rows of arima_data
# Out:
#                  Date  WVHT
# 2 2017-01-01 00:50:00  1.97
# 3 2017-01-01 01:50:00  2.02
# 4 2017-01-01 02:50:00  2.08
# 5 2017-01-01 03:50:00  1.95
# 6 2017-01-01 04:50:00  1.69

# %% [markdown]
# Next, we want to set the date as the index (the row labels).

# %%
arima_data = arima_data.set_index('Date') # setting date column to index
arima_data
# Out:
#                      WVHT
# Date
# 2017-01-01 00:50:00  1.97
# 2017-01-01 01:50:00  2.02
# 2017-01-01 02:50:00  2.08
# 2017-01-01 03:50:00  1.95
# 2017-01-01 04:50:00  1.69
# ...                   ...
# 2017-12-31 18:50:00  1.39
# 2017-12-31 19:50:00  1.54
# 2017-12-31 20:50:00  1.60
# 2017-12-31 21:50:00  1.53
# 2017-12-31 22:50:00  1.59
#
# [8643 rows x 1 columns]

# %% [markdown]
# Let's try to see what our data looks like.
#
# Our data represents wave heights in our selected buoy area for the year 2017.

# %%
arima_data['WVHT'] = arima_data['WVHT'].astype(float) # changing the datatype for WVHT for a nicer look on the plot
plt.figure(figsize=(10,6)) # setting up the dimentions for our plot
plt.title('2017 Wave Height Measurements (m) for Kauai Island Station 51101') # setting up a title
plt.plot(arima_data['WVHT']) # plotting our data

# %% [markdown]
# ## Splitting Data for Training and Testing
#
# For supervised machine learning, it's common to split your data for training and testing.
#
# We'll be splitting our data 80-20, meaning 80% of our data will be used to train our ARIMA model while we use the other 20% to test how well our model did.
#
# The training data will be stored in a new variable called *arima_train* while the testing data will be stored in *arima_test*.

# %%
arima_tts = arima_data['WVHT']
arima_train = arima_tts[:int(len(arima_data)*0.8)] # selecting 80% of arima_data for training
arima_test = arima_tts[int(len(arima_data)*0.8):] # selecting the last 20% of data for testing

# %% [markdown]
# Let's double check to make sure our train-test-split went smoothly (that the numbers add up).

# %%
print(len(arima_train)) # printing the length of arima_train
print(len(arima_test)) # printing the length of arima_test
print(len(arima_data)) # arima_train + arima_test should equal arima_data
# Out:
# 6915
# 1729
# 8644

# %% [markdown]
# ## ARIMA Parameters and Testing for Stationarity
#
# ARIMA models have 3 parameters (p, q, d):
#
# - AR = p (found from pacf plot)
# - MA = q (found from acf plot)
# - The number of differencing = d
#
# ------
#
# In order to determine d, we need to figure out if our data is stationary.
#
# Stationary means that your data has a constant mean, variance, and covariance that is independent of time. We can test for stationarity using the Augmented Dickey Fuller (ADF) test.
#
# If your data is **NOT** stationary, we would need to difference it.

# %%
adf_test = adfuller(arima_data['WVHT']) # performing adf test
print('ADF Statistic: ', adf_test[0]) # printing results
print('P-value: ', adf_test[1])
# Out:
# ADF Statistic:  -7.141465457408021
# P-value:  3.31570354059651e-10

# %% [markdown]
# If your p-value is > .05, your time series is not stationary.
#
# If it is < .05, your time series is stationary.
#
# Based on the p-value, our data is *not* stationary.
#
# Because it is not stationary, we need to perform differencing (in order to figure out what the d parameter will be).

# %%
arima_train_diff = arima_train.diff().dropna() # first order differencing

plt.figure(figsize=(10, 6)) # setting up plot size
plt.title('First Order Differencing')
plt.plot(arima_train_diff) # plotting differencing results

# %% [markdown]
# Since we performed differencing *once*, our d parameter will be equal to 1. Now let's figure out p and q using autocorrelation and partial correlation plots.

# %%
acf_plot = plot_acf(arima_train.diff().dropna()) # autocorrelation plot using training data

# %%
pacf_plot = plot_pacf(arima_train.diff().dropna()) # partial autocorrelation plot on training data

# %% [markdown]
# Based on this plot, we can see that 1 is significant, so p will equal 1.
#
# Based on the acf_plot, it appears to tail off at 2, so we will use 2 for q.
#
# Our parameters for now will be 1,2,1.

# %% [markdown]
# ### Auto Arima
#
# There's a cool function called auto_arima that is a statistical algorithm for determining the optimal parameters for ARIMA.
#
# Running this code might take a minute.

# %%
import pmdarima as pm # importing the package

auto_arima = pm.auto_arima(arima_train, stepwise = False, seasonal = False) # using auto arima on the training data

auto_arima # printing variable
# Out:
# ARIMA(order=(1, 1, 2), scoring_args={}, suppress_warnings=True)

# %% [markdown]
# Based on these results, the optimal parameters are 1,1,2 (we were close!). We'll use that instead when building out our ARIMA model.

# %% [markdown]
# ## Building the Model
#
# Below we use this code to build and print out the predicted and expected wave heights for the test.
#
# This code might take a couple of minutes.

# %%
waveheight_values = arima_data.WVHT
history = [x for x in arima_train]
predictions = list()
for t in range(len(arima_test)):
  model = ARIMA(history, order=(1,1,2)) # input the paramaters here within order=()
  model_fit = model.fit()
  output = model_fit.forecast()
  yhat = output[0]
  predictions.append(yhat)
  obs = arima_test[t]
  history.append(obs)
  print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# predicted=3.121223, expected=3.120000
# predicted=3.120443, expected=3.070000
# predicted=3.089651, expected=2.890000
# predicted=2.963137, expected=3.070000
# predicted=3.005324, expected=2.960000
# predicted=2.977777, expected=3.130000
# predicted=3.065660, expected=3.020000
# predicted=3.051192, expected=3.210000
# predicted=3.149351, expected=3.340000
# predicted=3.282153, expected=3.420000
# predicted=3.393427, expected=3.230000
# predicted=3.321176, expected=3.250000
# predicted=3.274189, expected=3.340000
# predicted=3.305211, expected=3.090000
# predicted=3.176839, expected=3.070000
# predicted=3.091155, expected=2.850000
# predicted=2.923807, expected=2.880000
# predicted=2.862735, expected=2.760000
# predicted=2.779439, expected=2.900000
# predicted=2.832422, expected=2.890000
# predicted=2.870122, expected=2.910000
# predicted=2.901523, expected=2.980000
# predicted=2.956689, expected=2.880000
# predicted=2.921602, expected=2.980000
# predicted=2.954715, expected=2.750000
# predicted=2.835125, expected=2.760000
# predicted=2.770809, expected=2.670000
# predicted=2.693044, expected=2.520000
# predicted=2.569735, expected=2.690000
# predicted=2.616640, expected=2.480000
# predicted=2.533537, expected=2.490000
# predicted=2.493046, expected=2.420000
# predicted=2.437570, expected=2.500000
# predicted=2.462818, expected=2.430000
# predicted=2.443281, expected=2.510000
# predicted=2.480666, expected=2.470000
# predicted=2.479531, expected=2.500000
# predicted=2.493397, expected=2.440000
# predicted=2.463713, expected=2.170000
# predicted=2.281001, expected=2.160000
# predicted=2.175352, expected=2.190000
# predicted=2.156783, expected=2.010000
# predicted=2.056038, expected=2.070000
# predicted=2.044081, expected=2.110000
# predicted=2.075981, expected=2.170000
# predicted=2.136078, expected=2.120000
# predicted=2.137312, expected=2.140000
# predicted=2.142475, expected=2.080000
# predicted=2.106419, expected=1.830000
# predicted=1.932801, expected=2.010000
# predicted=1.948833, expected=2.080000
# predicted=2.021996, expected=1.920000
# predicted=1.970267, expected=1.800000
# predicted=1.861117, expected=1.940000
# predicted=1.889043, expected=1.980000
# predicted=1.942958, expected=1.890000
# predicted=1.919392, expected=2.120000
# predicted=2.040021, expected=2.230000
# predicted=2.175462, expected=2.340000
# predicted=2.304409, expected=2.230000
# predicted=2.289536, expected=2.290000
# predicted=2.296536, expected=2.090000
# predicted=2.174027, expected=2.000000
# predicted=2.048436, expected=1.990000
# predicted=1.985837, expected=2.050000
# predicted=2.006276, expected=2.030000
# predicted=2.018568, expected=2.350000
# predicted=2.221795, expected=2.350000
# predicted=2.334515, expected=2.520000
# predicted=2.476797, expected=2.240000
# predicted=2.365097, expected=2.590000
# predicted=2.492847, expected=2.560000
# predicted=2.552581, expected=2.460000
# predicted=2.511884, expected=2.660000
# predicted=2.599761, expected=2.560000
# predicted=2.589756, expected=2.340000
# predicted=2.440306, expected=2.290000
# predicted=2.324312, expected=2.530000
# predicted=2.422721, expected=2.380000
# predicted=2.405355, expected=2.560000
# predicted=2.499098, expected=2.700000
# predicted=2.637081, expected=2.620000
# predicted=2.654592, expected=2.210000
# predicted=2.395119, expected=2.400000
# predicted=2.357901, expected=2.430000
# predicted=2.383654, expected=2.440000
# predicted=2.416840, expected=2.400000
# predicted=2.411805, expected=2.290000
# predicted=2.338376, expected=2.420000
# predicted=2.375983, expected=2.470000
# predicted=2.435879, expected=2.210000
# predicted=2.309272, expected=2.040000
# predicted=2.127425, expected=2.420000
# predicted=2.269762, expected=2.470000
# predicted=2.404579, expected=3.110000
# predicted=2.861124, expected=3.550000
# predicted=3.367611, expected=3.700000
# predicted=3.681406, expected=4.000000
# predicted=3.962970, expected=3.650000
# predicted=3.840804, expected=3.730000
# predicted=3.772491, expected=4.370000
# predicted=4.130697, expected=4.840000
# predicted=4.624077, expected=4.890000
# predicted=4.884852, expected=5.070000
# predicted=5.073915, expected=5.230000
# predicted=5.226308, expected=5.140000
# predicted=5.215821, expected=5.060000
# predicted=5.131906, expected=5.640000
# predicted=5.438291, expected=5.270000
# predicted=5.379727, expected=5.270000
# predicted=5.318346, expected=5.220000
# predicted=5.249955, expected=4.790000
# predicted=4.951963, expected=5.360000
# predicted=5.151693, expected=4.550000
# predicted=4.795504, expected=4.800000
# predicted=4.745003, expected=4.830000
# predicted=4.771561, expected=4.270000
# predicted=4.458488, expected=4.870000
# predicted=4.658538, expected=4.190000
# predicted=4.387090, expected=4.480000
# predicted=4.403798, expected=4.550000
# predicted=4.483384, expected=4.750000
# predicted=4.657100, expected=4.640000
# predicted=4.678956, expected=4.240000
# predicted=4.423571, expected=4.870000
# predicted=4.658846, expected=4.170000
# predicted=4.387469, expected=4.170000
# predicted=4.217007, expected=4.250000
# predicted=4.196644, expected=3.990000
# predicted=4.054189, expected=4.870000
# predicted=4.523402, expected=4.610000
# predicted=4.647566, expected=4.600000
# predicted=4.661030, expected=5.050000
# predicted=4.913939, expected=4.720000
# predicted=4.843355, expected=4.240000
# predicted=4.476595, expected=4.470000
# predicted=4.410543, expected=4.300000
# predicted=4.313377, expected=3.740000
# predicted=3.937680, expected=3.980000
# predicted=3.891224, expected=3.690000
# predicted=3.739227, expected=3.630000
# predicted=3.637604, expected=3.860000
# predicted=3.745910, expected=3.650000
# predicted=3.698218, expected=3.620000
# predicted=3.645265, expected=3.370000
# predicted=3.466494, expected=3.190000
# predicted=3.263395, expected=3.340000
# predicted=3.265136, expected=3.570000
# predicted=3.438683, expected=3.510000
# predicted=3.508362, expected=3.220000
# predicted=3.351524, expected=3.000000
# predicted=3.115599, expected=3.160000
# predicted=3.096552, expected=3.150000
# predicted=3.111971, expected=3.130000
# predicted=3.120332, expected=3.260000
# predicted=3.206431, expected=3.140000
# predicted=3.180548, expected=2.860000
# predicted=2.984502, expected=2.880000
# predicted=2.887525, expected=2.900000
# predicted=2.868694, expected=2.750000
# predicted=2.784702, expected=2.710000
# predicted=2.721310, expected=2.390000
# predicted=2.502233, expected=2.750000
# predicted=2.611951, expected=2.810000
# predicted=2.738803, expected=2.580000
# predicted=2.664612, expected=2.610000
# predicted=2.625848, expected=2.640000
# predicted=2.626343, expected=2.920000
# predicted=2.803584, expected=2.800000
# predicted=2.830400, expected=2.480000
# predicted=2.629502, expected=2.850000
# predicted=2.734948, expected=3.240000
# predicted=3.052506, expected=3.170000
# predicted=3.179832, expected=3.610000
# predicted=3.482650, expected=3.250000
# predicted=3.402813, expected=3.330000
# predicted=3.364726, expected=3.970000
# predicted=3.731811, expected=3.970000
# predicted=3.937471, expected=4.190000
# predicted=4.146129, expected=5.050000
# predicted=4.755337, expected=4.530000
# predicted=4.735467, expected=4.950000
# predicted=4.904089, expected=4.550000
# predicted=4.725919, expected=4.540000
# predicted=4.594229, expected=4.760000
# predicted=4.668657, expected=4.130000
# predicted=4.342231, expected=4.030000
# predicted=4.096203, expected=4.190000
# predicted=4.094891, expected=4.120000
# predicted=4.091698, expected=3.970000
# predicted=4.010592, expected=4.210000
# predicted=4.117123, expected=4.660000
# predicted=4.463484, expected=4.100000
# predicted=4.304008, expected=3.930000
# predicted=4.066970, expected=3.940000
# predicted=3.946936, expected=3.790000
# predicted=3.817045, expected=3.370000
# predicted=3.510025, expected=3.400000
# predicted=3.380112, expected=3.410000
# predicted=3.357112, expected=3.540000
# predicted=3.452930, expected=3.920000
# predicted=3.751626, expected=3.400000
# predicted=3.589550, expected=3.360000
# predicted=3.437715, expected=3.440000
# predicted=3.410401, expected=3.900000
# predicted=3.697655, expected=3.610000
# predicted=3.687447, expected=3.370000
# predicted=3.504666, expected=3.160000
# predicted=3.266520, expected=2.860000
# predicted=2.968302, expected=3.120000
# predicted=2.997210, expected=2.790000
# predicted=2.853534, expected=2.750000
# predicted=2.760780, expected=2.970000
# predicted=2.864868, expected=2.810000
# predicted=2.840500, expected=2.810000
# predicted=2.820695, expected=2.430000
# predicted=2.576841, expected=2.640000
# predicted=2.574149, expected=2.690000
# predicted=2.631517, expected=2.580000
# predicted=2.604819, expected=2.470000
# predicted=2.519115, expected=2.400000
# predicted=2.430809, expected=2.260000
# predicted=2.306271, expected=2.120000
# predicted=2.164734, expected=2.160000
# predicted=2.129663, expected=2.140000
# predicted=2.119728, expected=2.250000
# predicted=2.192959, expected=2.270000
# predicted=2.250201, expected=2.110000
# predicted=2.176554, expected=1.910000
# predicted=2.004514, expected=1.970000
# predicted=1.952420, expected=1.800000
# predicted=1.839864, expected=1.890000
# predicted=1.846105, expected=1.790000
# predicted=1.804515, expected=1.750000
# predicted=1.761794, expected=1.720000
# predicted=1.726032, expected=1.670000
# predicted=1.682362, expected=1.690000
# predicted=1.676866, expected=1.600000
# predicted=1.625293, expected=1.460000
# predicted=1.513648, expected=1.380000
# predicted=1.409739, expected=1.570000
# predicted=1.484231, expected=1.510000
# predicted=1.504344, expected=1.450000
# predicted=1.475577, expected=1.370000
# predicted=1.407402, expected=1.390000
# predicted=1.384466, expected=1.300000
# predicted=1.324648, expected=1.280000
# predicted=1.284758, expected=1.270000
# predicted=1.265021, expected=1.370000
# predicted=1.322900, expected=1.180000
# predicted=1.242168, expected=1.240000
# predicted=1.229995, expected=1.410000
# predicted=1.335220, expected=1.320000
# predicted=1.341257, expected=1.340000
# predicted=1.346579, expected=1.150000
# predicted=1.228453, expected=1.270000
# predicted=1.235631, expected=1.300000
# predicted=1.270333, expected=1.290000
# predicted=1.286485, expected=1.270000
# predicted=1.280325, expected=1.230000
# predicted=1.249661, expected=1.210000
# predicted=1.220330, expected=1.180000
# predicted=1.189066, expected=1.240000
# predicted=1.213164, expected=1.250000
# predicted=1.237373, expected=1.250000
# predicted=1.249619, expected=1.300000
# predicted=1.284126, expected=1.380000
# predicted=1.349960, expected=1.340000
# predicted=1.356870, expected=1.380000
# predicted=1.376575, expected=1.620000
# predicted=1.531495, expected=1.660000
# predicted=1.637692, expected=1.790000
# predicted=1.757933, expected=2.180000
# predicted=2.046711, expected=2.160000
# predicted=2.173544, expected=2.330000
# predicted=2.310036, expected=2.570000
# predicted=2.506594, expected=2.760000
# predicted=2.707745, expected=3.020000
# predicted=2.949290, expected=3.040000
# predicted=3.061786, expected=2.910000
# predicted=3.005624, expected=3.250000
# predicted=3.160798, expected=2.830000
# predicted=2.983051, expected=3.260000
# predicted=3.133842, expected=3.150000
# predicted=3.161865, expected=2.910000
# predicted=3.017300, expected=3.190000
# predicted=3.103514, expected=3.040000
# predicted=3.071752, expected=2.830000
# predicted=2.919940, expected=3.190000
# predicted=3.060249, expected=3.010000
# predicted=3.043724, expected=2.990000
# predicted=3.012770, expected=2.810000
# predicted=2.883393, expected=2.920000
# predicted=2.882982, expected=3.120000
# predicted=3.021191, expected=2.840000
# predicted=2.929772, expected=2.990000
# predicted=2.958605, expected=2.710000
# predicted=2.807470, expected=2.850000
# predicted=2.809220, expected=2.510000
# predicted=2.616939, expected=2.920000
# predicted=2.768714, expected=2.710000
# predicted=2.746210, expected=3.040000
# predicted=2.927848, expected=3.130000
# predicted=3.083006, expected=2.860000
# predicted=2.981887, expected=3.040000
# predicted=3.012818, expected=2.860000
# predicted=2.922314, expected=2.540000
# predicted=2.672989, expected=2.760000
# predicted=2.680137, expected=2.700000
# predicted=2.678262, expected=2.420000
# predicted=2.514353, expected=2.470000
# predicted=2.457891, expected=2.490000
# predicted=2.458526, expected=2.550000
# predicted=2.508597, expected=2.500000
# predicted=2.509656, expected=2.350000
# predicted=2.413696, expected=2.070000
# predicted=2.186842, expected=2.220000
# predicted=2.164286, expected=2.220000
# predicted=2.180467, expected=2.040000
# predicted=2.090618, expected=2.030000
# predicted=2.037160, expected=2.090000
# predicted=2.055354, expected=2.070000
# predicted=2.062605, expected=1.830000
# predicted=1.920056, expected=1.830000
# predicted=1.841047, expected=2.030000
# predicted=1.936251, expected=1.730000
# predicted=1.818116, expected=1.840000
# predicted=1.814812, expected=1.990000
# predicted=1.916406, expected=1.890000
# predicted=1.915047, expected=1.800000
# predicted=1.849036, expected=1.770000
# predicted=1.791010, expected=1.810000
# predicted=1.789857, expected=1.780000
# predicted=1.779270, expected=1.900000
# predicted=1.850252, expected=1.640000
# predicted=1.731646, expected=1.770000
# predicted=1.739073, expected=1.680000
# predicted=1.698531, expected=1.840000
# predicted=1.777346, expected=1.830000
# predicted=1.820130, expected=1.880000
# predicted=1.867595, expected=1.650000
# predicted=1.745267, expected=1.660000
# predicted=1.676308, expected=1.760000
# predicted=1.710746, expected=1.570000
# predicted=1.624166, expected=1.580000
# predicted=1.582564, expected=1.530000
# predicted=1.538430, expected=1.580000
# predicted=1.552657, expected=1.520000
# predicted=1.531122, expected=1.630000
# predicted=1.587854, expected=1.610000
# predicted=1.609566, expected=1.680000
# predicted=1.659230, expected=1.870000
# predicted=1.799289, expected=1.800000
# predicted=1.826621, expected=1.670000
# predicted=1.743872, expected=1.720000
# predicted=1.719962, expected=1.710000
# predicted=1.706743, expected=1.820000
# predicted=1.771823, expected=1.690000
# predicted=1.730797, expected=1.790000
# predicted=1.763500, expected=1.820000
# predicted=1.802452, expected=1.840000
# predicted=1.833454, expected=1.760000
# predicted=1.796111, expected=1.680000
# predicted=1.721109, expected=1.880000
# predicted=1.805120, expected=1.850000
# predicted=1.842097, expected=1.870000
# predicted=1.868575, expected=1.870000
# predicted=1.877004, expected=1.630000
# predicted=1.729045, expected=1.860000
# predicted=1.786274, expected=1.770000
# predicted=1.777933, expected=1.830000
# predicted=1.809118, expected=1.960000
# predicted=1.906808, expected=1.910000
# predicted=1.926700, expected=1.670000
# predicted=1.778202, expected=2.070000
# predicted=1.935965, expected=1.820000
# predicted=1.883754, expected=1.710000
# predicted=1.774692, expected=1.750000
# predicted=1.740543, expected=1.800000
# predicted=1.764998, expected=1.700000
# predicted=1.725078, expected=1.730000
# predicted=1.721445, expected=1.580000
# predicted=1.631698, expected=1.700000
# predicted=1.657722, expected=1.580000
# predicted=1.608957, expected=1.530000
# predicted=1.551965, expected=1.670000
# predicted=1.612097, expected=1.760000
# predicted=1.708839, expected=1.870000
# predicted=1.826005, expected=1.830000
# predicted=1.854095, expected=1.830000
# predicted=1.852588, expected=1.740000
# predicted=1.787605, expected=1.750000
# predicted=1.755072, expected=1.790000
# predicted=1.767957, expected=1.880000
# predicted=1.836076, expected=1.850000
# predicted=1.855722, expected=1.820000
# predicted=1.840771, expected=1.970000
# predicted=1.920057, expected=2.020000
# predicted=1.994647, expected=2.010000
# predicted=2.020937, expected=2.210000
# predicted=2.147210, expected=2.210000
# predicted=2.210250, expected=2.140000
# predicted=2.185795, expected=2.140000
# predicted=2.159875, expected=2.190000
# predicted=2.174835, expected=2.060000
# predicted=2.105534, expected=2.140000
# predicted=2.115602, expected=2.160000
# predicted=2.140832, expected=1.990000
# predicted=2.051655, expected=1.970000
# predicted=1.987783, expected=2.060000
# predicted=2.016916, expected=1.920000
# predicted=1.957081, expected=2.160000
# predicted=2.071695, expected=2.110000
# predicted=2.110981, expected=2.200000
# predicted=2.177532, expected=2.160000
# predicted=2.181832, expected=1.990000
# predicted=2.069699, expected=2.110000
# predicted=2.077708, expected=2.210000
# predicted=2.154726, expected=2.320000
# predicted=2.267692, expected=2.210000
# predicted=2.254829, expected=2.110000
# predicted=2.171288, expected=2.090000
# predicted=2.109317, expected=2.250000
# predicted=2.181484, expected=2.250000
# predicted=2.230696, expected=2.290000
# predicted=2.277708, expected=2.430000
# predicted=2.382720, expected=2.440000
# predicted=2.439204, expected=2.330000
# predicted=2.388612, expected=2.430000
# predicted=2.411306, expected=2.360000
# predicted=2.382577, expected=2.300000
# predicted=2.327999, expected=2.210000
# predicted=2.245106, expected=2.210000
# predicted=2.206279, expected=2.180000
# predicted=2.177851, expected=2.130000
# predicted=2.139561, expected=2.230000
# predicted=2.185830, expected=2.310000
# predicted=2.266711, expected=2.410000
# predicted=2.369792, expected=2.120000
# predicted=2.238297, expected=2.350000
# predicted=2.292645, expected=2.220000
# predicted=2.252166, expected=2.120000
# predicted=2.165609, expected=1.880000
# predicted=1.973825, expected=1.940000
# predicted=1.915726, expected=1.800000
# predicted=1.822353, expected=1.740000
# predicted=1.748701, expected=1.690000
# predicted=1.692606, expected=1.840000
# predicted=1.767253, expected=1.930000
# predicted=1.874455, expected=1.790000
# predicted=1.842684, expected=1.860000
# predicted=1.854811, expected=1.800000
# predicted=1.823613, expected=1.860000
# predicted=1.841639, expected=1.900000
# predicted=1.879073, expected=1.590000
# predicted=1.708085, expected=1.840000
# predicted=1.762945, expected=1.770000
# predicted=1.767666, expected=1.720000
# predicted=1.739282, expected=1.760000
# predicted=1.747589, expected=1.600000
# predicted=1.656785, expected=1.630000
# predicted=1.625150, expected=1.710000
# predicted=1.666968, expected=1.680000
# predicted=1.678493, expected=1.660000
# predicted=1.670220, expected=1.510000
# predicted=1.571394, expected=1.570000
# predicted=1.553968, expected=1.360000
# predicted=1.426283, expected=1.420000
# predicted=1.398315, expected=1.350000
# predicted=1.355895, expected=1.340000
# predicted=1.334802, expected=1.350000
# predicted=1.336848, expected=1.400000
# predicted=1.373578, expected=1.370000
# predicted=1.376804, expected=1.430000
# predicted=1.411854, expected=1.330000
# predicted=1.368169, expected=1.430000
# predicted=1.401097, expected=1.450000
# predicted=1.434956, expected=1.230000
# predicted=1.315910, expected=1.350000
# predicted=1.319299, expected=1.320000
# predicted=1.314441, expected=1.210000
# predicted=1.247688, expected=1.160000
# predicted=1.181795, expected=1.150000
# predicted=1.147252, expected=1.200000
# predicted=1.168905, expected=1.210000
# predicted=1.194188, expected=1.230000
# predicted=1.220428, expected=1.200000
# predicted=1.213661, expected=1.220000
# predicted=1.218356, expected=1.230000
# predicted=1.226563, expected=1.240000
# predicted=1.236541, expected=1.240000
# predicted=1.240905, expected=1.400000
# predicted=1.340153, expected=1.300000
# predicted=1.332538, expected=1.190000
# predicted=1.249353, expected=1.340000
# predicted=1.292652, expected=1.290000
# predicted=1.294109, expected=1.450000
# predicted=1.391173, expected=1.520000
# predicted=1.486969, expected=1.480000
# predicted=1.504203, expected=1.520000
# predicted=1.523973, expected=1.770000
# predicted=1.681865, expected=1.830000
# predicted=1.801531, expected=1.840000
# predicted=1.854715, expected=1.860000
# predicted=1.876740, expected=1.980000
# predicted=1.950240, expected=1.750000
# predicted=1.842697, expected=2.180000
# predicted=2.037276, expected=1.910000
# predicted=1.987348, expected=2.250000
# predicted=2.149735, expected=2.200000
# predicted=2.208231, expected=2.450000
# predicted=2.375796, expected=2.480000
# predicted=2.474336, expected=2.310000
# predicted=2.401367, expected=2.630000
# predicted=2.538922, expected=2.690000
# predicted=2.653940, expected=2.670000
# predicted=2.690533, expected=2.520000
# predicted=2.600863, expected=2.590000
# predicted=2.584210, expected=2.440000
# predicted=2.489449, expected=2.380000
# predicted=2.404236, expected=2.260000
# predicted=2.295284, expected=2.530000
# predicted=2.414415, expected=2.530000
# predicted=2.497117, expected=2.430000
# predicted=2.473601, expected=2.370000
# predicted=2.411928, expected=2.290000
# predicted=2.327354, expected=2.230000
# predicted=2.250133, expected=2.410000
# predicted=2.329647, expected=2.190000
# predicted=2.250862, expected=2.240000
# predicted=2.233353, expected=2.310000
# predicted=2.273880, expected=1.920000
# predicted=2.061116, expected=2.040000
# predicted=2.014026, expected=2.350000
# predicted=2.201125, expected=2.300000
# predicted=2.286585, expected=2.370000
# predicted=2.360433, expected=2.210000
# predicted=2.287890, expected=2.220000
# predicted=2.240828, expected=2.410000
# predicted=2.335180, expected=1.930000
# predicted=2.098829, expected=2.000000
# predicted=2.002835, expected=2.070000
# predicted=2.016239, expected=2.050000
# predicted=2.029852, expected=2.060000
# predicted=2.048249, expected=1.980000
# predicted=2.009353, expected=1.890000
# predicted=1.930581, expected=2.170000
# predicted=2.062602, expected=1.970000
# predicted=2.022747, expected=1.940000
# predicted=1.971013, expected=1.960000
# predicted=1.955307, expected=1.730000
# predicted=1.811357, expected=1.770000
# predicted=1.760033, expected=1.900000
# predicted=1.828701, expected=1.890000
# predicted=1.871972, expected=1.900000
# predicted=1.898291, expected=1.740000
# predicted=1.808540, expected=1.670000
# predicted=1.711053, expected=1.950000
# predicted=1.837368, expected=1.700000
# predicted=1.767153, expected=1.670000
# predicted=1.700609, expected=1.890000
# predicted=1.803412, expected=1.950000
# predicted=1.905964, expected=1.980000
# predicted=1.972726, expected=1.910000
# predicted=1.952524, expected=1.850000
# predicted=1.892424, expected=1.990000
# predicted=1.943316, expected=2.000000
# predicted=1.983509, expected=1.950000
# predicted=1.971442, expected=1.730000
# predicted=1.824120, expected=1.990000
# predicted=1.901768, expected=1.740000
# predicted=1.807213, expected=1.620000
# predicted=1.678194, expected=1.770000
# predicted=1.708278, expected=1.840000
# predicted=1.785218, expected=1.750000
# predicted=1.775064, expected=1.730000
# predicted=1.749609, expected=1.730000
# predicted=1.734100, expected=1.750000
# predicted=1.740099, expected=1.600000
# predicted=1.653863, expected=1.660000
# predicted=1.643207, expected=1.660000
# predicted=1.646844, expected=1.730000
# predicted=1.696206, expected=1.610000
# predicted=1.650949, expected=1.740000
# predicted=1.700656, expected=1.770000
# predicted=1.749786, expected=1.570000
# predicted=1.649898, expected=1.680000
# predicted=1.655292, expected=1.760000
# predicted=1.715986, expected=1.800000
# predicted=1.776400, expected=1.680000
# predicted=1.730309, expected=1.760000
# predicted=1.745308, expected=1.830000
# predicted=1.798659, expected=1.970000
# predicted=1.913103, expected=1.800000
# predicted=1.865889, expected=1.990000
# predicted=1.941725, expected=2.270000
# predicted=2.155659, expected=2.590000
# predicted=2.462301, expected=2.380000
# predicted=2.476034, expected=2.480000
# predicted=2.502913, expected=2.710000
# predicted=2.643161, expected=2.670000
# predicted=2.687330, expected=2.860000
# predicted=2.810374, expected=2.940000
# predicted=2.916307, expected=3.250000
# predicted=3.148169, expected=3.310000
# predicted=3.295443, expected=3.410000
# predicted=3.407076, expected=3.540000
# predicted=3.521906, expected=3.280000
# predicted=3.403516, expected=3.420000
# predicted=3.404836, expected=3.530000
# predicted=3.479029, expected=3.440000
# predicted=3.466236, expected=3.230000
# predicted=3.322816, expected=2.970000
# predicted=3.082664, expected=3.090000
# predicted=3.039487, expected=3.230000
# predicted=3.132855, expected=3.150000
# predicted=3.150217, expected=3.180000
# predicted=3.173829, expected=2.900000
# predicted=3.010979, expected=3.130000
# predicted=3.059601, expected=3.060000
# predicted=3.059031, expected=3.140000
# predicted=3.108462, expected=3.350000
# predicted=3.265063, expected=3.440000
# predicted=3.401280, expected=3.460000
# predicted=3.469912, expected=3.730000
# predicted=3.652936, expected=3.530000
# predicted=3.615385, expected=3.530000
# predicted=3.570138, expected=3.400000
# predicted=3.460464, expected=3.840000
# predicted=3.674485, expected=3.540000
# predicted=3.619838, expected=3.560000
# predicted=3.584042, expected=3.560000
# predicted=3.563730, expected=3.420000
# predicted=3.470020, expected=3.440000
# predicted=3.434266, expected=3.490000
# predicted=3.456554, expected=3.340000
# predicted=3.384271, expected=3.250000
# predicted=3.289566, expected=3.150000
# predicted=3.183825, expected=3.420000
# predicted=3.304703, expected=3.330000
# predicted=3.331442, expected=3.520000
# predicted=3.455841, expected=3.480000
# predicted=3.494118, expected=3.330000
# predicted=3.407696, expected=3.440000
# predicted=3.418554, expected=3.400000
# predicted=3.405723, expected=3.380000
# predicted=3.387291, expected=3.340000
# predicted=3.354249, expected=3.300000
# predicted=3.314052, expected=3.190000
# predicted=3.228715, expected=3.230000
# predicted=3.212292, expected=3.160000
# predicted=3.171326, expected=3.120000
# predicted=3.129901, expected=2.920000
# predicted=2.990443, expected=2.980000
# predicted=2.957451, expected=3.370000
# predicted=3.196471, expected=3.250000
# predicted=3.263294, expected=3.170000
# predicted=3.228807, expected=2.930000
# predicted=3.047423, expected=3.050000
# predicted=3.020494, expected=3.130000
# predicted=3.073310, expected=2.910000
# predicted=2.976096, expected=2.730000
# predicted=2.809977, expected=2.780000
# predicted=2.759256, expected=2.600000
# predicted=2.641280, expected=2.500000
# predicted=2.527866, expected=2.770000
# predicted=2.649027, expected=2.640000
# predicted=2.653097, expected=2.450000
# predicted=2.532124, expected=2.610000
# predicted=2.561919, expected=2.520000
# predicted=2.534381, expected=2.640000
# predicted=2.594281, expected=2.500000
# predicted=2.544155, expected=2.430000
# predicted=2.468606, expected=2.480000
# predicted=2.461426, expected=2.590000
# predicted=2.534248, expected=2.230000
# predicted=2.356605, expected=2.280000
# predicted=2.284045, expected=2.440000
# predicted=2.359010, expected=2.470000
# predicted=2.431851, expected=2.490000
# predicted=2.481101, expected=2.490000
# predicted=2.499454, expected=2.320000
# predicted=2.396664, expected=2.320000
# predicted=2.335623, expected=2.360000
# predicted=2.335711, expected=2.580000
# predicted=2.480668, expected=2.440000
# predicted=2.477044, expected=2.300000
# predicted=2.375299, expected=2.400000
# predicted=2.376772, expected=2.200000
# predicted=2.263165, expected=2.070000
# predicted=2.124147, expected=2.130000
# predicted=2.097971, expected=2.450000
# predicted=2.299636, expected=2.610000
# predicted=2.517795, expected=2.570000
# predicted=2.594745, expected=2.680000
# predicted=2.676078, expected=2.400000
# predicted=2.529337, expected=2.780000
# predicted=2.668988, expected=2.790000
# predicted=2.760518, expected=2.910000
# predicted=2.873497, expected=2.950000
# predicted=2.946417, expected=2.590000
# predicted=2.747917, expected=2.660000
# predicted=2.669910, expected=2.500000
# predicted=2.543852, expected=2.710000
# predicted=2.618389, expected=2.680000
# predicted=2.657913, expected=2.700000
# predicted=2.690715, expected=2.730000
# predicted=2.722691, expected=3.190000
# predicted=3.018727, expected=3.120000
# predicted=3.131412, expected=2.960000
# predicted=3.062015, expected=3.210000
# predicted=3.155653, expected=3.360000
# predicted=3.297567, expected=3.470000
# predicted=3.432433, expected=3.690000
# predicted=3.623490, expected=3.900000
# predicted=3.836735, expected=3.990000
# predicted=3.981342, expected=4.040000
# predicted=4.059377, expected=4.420000
# predicted=4.310771, expected=4.220000
# predicted=4.305342, expected=3.830000
# predicted=4.029562, expected=4.390000
# predicted=4.215320, expected=4.580000
# predicted=4.456374, expected=4.060000
# predicted=4.255632, expected=4.060000
# predicted=4.120092, expected=4.260000
# predicted=4.179421, expected=3.950000
# predicted=4.036823, expected=4.700000
# predicted=4.422469, expected=3.930000
# predicted=4.172298, expected=3.830000
# predicted=3.941743, expected=3.930000
# predicted=3.890649, expected=4.020000
# predicted=3.945292, expected=4.130000
# predicted=4.057903, expected=3.420000
# predicted=3.682911, expected=3.700000
# predicted=3.641083, expected=3.840000
# predicted=3.736338, expected=3.440000
# predicted=3.558712, expected=3.490000
# predicted=3.490176, expected=3.910000
# predicted=3.726882, expected=3.480000
# predicted=3.604595, expected=3.710000
# predicted=3.661291, expected=3.680000
# predicted=3.678657, expected=3.290000
# predicted=3.445362, expected=3.620000
# predicted=3.517313, expected=3.290000
# predicted=3.375851, expected=3.370000
# predicted=3.348870, expected=3.120000
# predicted=3.195306, expected=3.320000
# predicted=3.242044, expected=3.390000
# predicted=3.328807, expected=3.510000
# predicted=3.452257, expected=3.570000
# predicted=3.548925, expected=3.820000
# predicted=3.739994, expected=3.450000
# predicted=3.602254, expected=3.620000
# predicted=3.606281, expected=3.310000
# predicted=3.422641, expected=3.290000
# predicted=3.311030, expected=3.300000
# predicted=3.274979, expected=3.800000
# predicted=3.580122, expected=3.580000
# predicted=3.622397, expected=3.580000
# predicted=3.619085, expected=3.660000
# predicted=3.652267, expected=3.400000
# predicted=3.505967, expected=3.420000
# predicted=3.433091, expected=3.520000
# predicted=3.467181, expected=3.660000
# predicted=3.583549, expected=3.560000
# predicted=3.586852, expected=3.490000
# predicted=3.534732, expected=3.490000
# predicted=3.501814, expected=3.320000
# predicted=3.383013, expected=3.460000
# predicted=3.408622, expected=3.440000
# predicted=3.423684, expected=3.120000
# predicted=3.238296, expected=3.490000
# predicted=3.363435, expected=3.110000
# predicted=3.217062, expected=3.260000
# predicted=3.223372, expected=3.070000
# predicted=3.122906, expected=3.150000
# predicted=3.120970, expected=3.180000
# predicted=3.149820, expected=3.070000
# predicted=3.102790, expected=3.340000
# predicted=3.241195, expected=3.130000
# predicted=3.192712, expected=3.790000
# predicted=3.557690, expected=3.730000
# predicted=3.721854, expected=3.300000
# predicted=3.511577, expected=3.550000
# predicted=3.519640, expected=3.540000
# predicted=3.527564, expected=3.770000
# predicted=3.675543, expected=3.720000
# predicted=3.726106, expected=3.440000
# predicted=3.567991, expected=3.520000
# predicted=3.519954, expected=3.600000
# predicted=3.554190, expected=3.610000
# predicted=3.588145, expected=3.870000
# predicted=3.765928, expected=3.740000
# predicted=3.780251, expected=3.690000
# predicted=3.738817, expected=3.950000
# predicted=3.866742, expected=4.240000
# predicted=4.115054, expected=4.060000
# predicted=4.128196, expected=3.850000
# predicted=3.977963, expected=4.440000
# predicted=4.244685, expected=4.600000
# predicted=4.498300, expected=5.100000
# predicted=4.921500, expected=5.040000
# predicted=5.081821, expected=4.910000
# predicted=5.035700, expected=4.890000
# predicted=4.962613, expected=4.320000
# predicted=4.561381, expected=4.740000
# predicted=4.607136, expected=4.450000
# predicted=4.492548, expected=4.520000
# predicted=4.484714, expected=4.310000
# predicted=4.366706, expected=4.040000
# predicted=4.143295, expected=4.330000
# predicted=4.214209, expected=4.930000
# predicted=4.648177, expected=4.280000
# predicted=4.487375, expected=4.170000
# predicted=4.292848, expected=4.090000
# predicted=4.138869, expected=4.260000
# predicted=4.178049, expected=4.310000
# predicted=4.250990, expected=4.220000
# predicted=4.239834, expected=4.240000
# predicted=4.241385, expected=3.950000
# predicted=4.063334, expected=3.960000
# predicted=3.973121, expected=3.870000
# predicted=3.885279, expected=4.220000
# predicted=4.067607, expected=4.040000
# predicted=4.068923, expected=3.900000
# predicted=3.972752, expected=4.050000
# predicted=4.008679, expected=4.150000
# predicted=4.096200, expected=4.090000
# predicted=4.105982, expected=4.230000
# predicted=4.189091, expected=4.400000
# predicted=4.334014, expected=4.150000
# predicted=4.249296, expected=3.780000
# predicted=3.959654, expected=4.170000
# predicted=4.044607, expected=3.860000
# predicted=3.926088, expected=3.710000
# predicted=3.773457, expected=3.740000
# predicted=3.721638, expected=3.990000
# predicted=3.865860, expected=4.300000
# predicted=4.146182, expected=3.930000
# predicted=4.061118, expected=4.320000
# predicted=4.226497, expected=4.120000
# predicted=4.188833, expected=3.570000
# predicted=3.814356, expected=4.130000
# predicted=3.953270, expected=4.100000
# predicted=4.042438, expected=4.230000
# predicted=4.170451, expected=3.770000
# predicted=3.949567, expected=4.170000
# predicted=4.061154, expected=3.690000
# predicted=3.841500, expected=3.690000
# predicted=3.718360, expected=3.640000
# predicted=3.639519, expected=3.600000
# predicted=3.590997, expected=3.680000
# predicted=3.628416, expected=3.510000
# predicted=3.554750, expected=3.690000
# predicted=3.625911, expected=3.490000
# predicted=3.548907, expected=3.900000
# predicted=3.754398, expected=3.460000
# predicted=3.602180, expected=3.590000
# predicted=3.582412, expected=3.590000
# predicted=3.579145, expected=3.380000
# predicted=3.453814, expected=3.430000
# predicted=3.418609, expected=3.370000
# predicted=3.375352, expected=3.160000
# predicted=3.231731, expected=3.130000
# predicted=3.142742, expected=3.200000
# predicted=3.153527, expected=3.160000
# predicted=3.149568, expected=3.330000
# predicted=3.256182, expected=3.170000
# predicted=3.218380, expected=2.980000
# predicted=3.072687, expected=2.900000
# predicted=2.944850, expected=2.810000
# predicted=2.833995, expected=3.110000
# predicted=2.974713, expected=2.920000
# predicted=2.951459, expected=3.070000
# predicted=3.024521, expected=3.180000
# predicted=3.130993, expected=3.170000
# predicted=3.175618, expected=3.340000
# predicted=3.291204, expected=3.150000
# predicted=3.228459, expected=3.050000
# predicted=3.119010, expected=3.030000
# predicted=3.047711, expected=3.010000
# predicted=3.007106, expected=3.100000
# predicted=3.050835, expected=3.180000
# predicted=3.131363, expected=2.860000
# predicted=2.978228, expected=3.210000
# predicted=3.101632, expected=3.570000
# predicted=3.399753, expected=3.590000
# predicted=3.566299, expected=3.810000
# predicted=3.760878, expected=4.330000
# predicted=4.157838, expected=4.010000
# predicted=4.146807, expected=3.950000
# predicted=4.055401, expected=4.060000
# predicted=4.055765, expected=4.090000
# predicted=4.075909, expected=3.800000
# predicted=3.909478, expected=3.600000
# predicted=3.695212, expected=4.060000
# predicted=3.876212, expected=3.780000
# predicted=3.828726, expected=3.740000
# predicted=3.771497, expected=3.780000
# predicted=3.766757, expected=3.470000
# predicted=3.580527, expected=3.930000
# predicted=3.763762, expected=3.840000
# predicted=3.826922, expected=3.570000
# predicted=3.685865, expected=3.790000
# predicted=3.734020, expected=4.000000
# predicted=3.898072, expected=3.650000
# predicted=3.772350, expected=3.670000
# predicted=3.700394, expected=3.640000
# predicted=3.648733, expected=3.490000
# predicted=3.537995, expected=3.430000
# predicted=3.449544, expected=3.320000
# predicted=3.347968, expected=3.160000
# predicted=3.208609, expected=3.190000
# predicted=3.166211, expected=3.220000
# predicted=3.180561, expected=2.980000
# predicted=3.052878, expected=3.080000
# predicted=3.047770, expected=3.370000
# predicted=3.235638, expected=2.870000
# predicted=3.037764, expected=3.040000
# predicted=3.018331, expected=3.120000
# predicted=3.069375, expected=2.990000
# predicted=3.024542, expected=3.290000
# predicted=3.181110, expected=2.960000
# predicted=3.068334, expected=3.060000
# predicted=3.054261, expected=2.870000
# predicted=2.936118, expected=2.740000
# predicted=2.795764, expected=2.970000
# predicted=2.872412, expected=3.140000
# predicted=3.036310, expected=3.060000
# predicted=3.076306, expected=2.670000
# predicted=2.844055, expected=3.000000
# predicted=2.909781, expected=2.720000
# predicted=2.792534, expected=2.590000
# predicted=2.650211, expected=2.440000
# predicted=2.492513, expected=2.410000
# predicted=2.406294, expected=2.630000
# predicted=2.515762, expected=2.580000
# predicted=2.561396, expected=2.570000
# predicted=2.576176, expected=2.280000
# predicted=2.401162, expected=2.430000
# predicted=2.394185, expected=2.450000
# predicted=2.417587, expected=2.610000
# predicted=2.534536, expected=2.540000
# predicted=2.555622, expected=2.650000
# predicted=2.623470, expected=2.600000
# predicted=2.623552, expected=2.450000
# predicted=2.523188, expected=2.570000
# predicted=2.538568, expected=2.400000
# predicted=2.451116, expected=2.470000
# predicted=2.448098, expected=2.580000
# predicted=2.522518, expected=2.500000
# predicted=2.517810, expected=2.770000
# predicted=2.674668, expected=2.650000
# predicted=2.684850, expected=2.510000
# predicted=2.589442, expected=2.630000
# predicted=2.603995, expected=2.620000
# predicted=2.612019, expected=2.600000
# predicted=2.605232, expected=2.440000
# predicted=2.503505, expected=2.460000
# predicted=2.460971, expected=2.400000
# predicted=2.410958, expected=2.450000
# predicted=2.422135, expected=2.510000
# predicted=2.472577, expected=2.350000
# predicted=2.404214, expected=2.640000
# predicted=2.540194, expected=2.640000
# predicted=2.618986, expected=2.570000
# predicted=2.608146, expected=2.570000
# predicted=2.590595, expected=2.390000
# predicted=2.467617, expected=2.550000
# predicted=2.498822, expected=2.350000
# predicted=2.405313, expected=2.360000
# predicted=2.362221, expected=2.420000
# predicted=2.384874, expected=2.300000
# predicted=2.331656, expected=2.530000
# predicted=2.443990, expected=2.380000
# predicted=2.418896, expected=2.720000
# predicted=2.604182, expected=2.490000
# predicted=2.563788, expected=2.760000
# predicted=2.688479, expected=3.030000
# predicted=2.918239, expected=3.130000
# predicted=3.091469, expected=3.190000
# predicted=3.195472, expected=3.750000
# predicted=3.567753, expected=3.580000
# predicted=3.646169, expected=3.430000
# predicted=3.553348, expected=3.130000
# predicted=3.294816, expected=3.150000
# predicted=3.166231, expected=3.400000
# predicted=3.274569, expected=2.760000
# predicted=2.963315, expected=3.140000
# predicted=3.023968, expected=2.920000
# predicted=2.952157, expected=3.110000
# predicted=3.034164, expected=2.960000
# predicted=2.996374, expected=3.000000
# predicted=2.995460, expected=2.960000
# predicted=2.972503, expected=3.070000
# predicted=3.027893, expected=2.750000
# predicted=2.865526, expected=2.960000
# predicted=2.900290, expected=3.310000
# predicted=3.147180, expected=3.080000
# predicted=3.143748, expected=3.410000
# predicted=3.319813, expected=3.430000
# predicted=3.419880, expected=3.400000
# predicted=3.435778, expected=3.200000
# predicted=3.304835, expected=3.650000
# predicted=3.499610, expected=3.430000
# predicted=3.481964, expected=3.110000
# predicted=3.261734, expected=3.170000
# predicted=3.173463, expected=3.250000
# predicted=3.194185, expected=3.200000
# predicted=3.191279, expected=3.100000
# predicted=3.132753, expected=3.190000
# predicted=3.157359, expected=3.120000
# predicted=3.134611, expected=3.280000
# predicted=3.219660, expected=3.030000
# predicted=3.116150, expected=3.360000
# predicted=3.252875, expected=3.090000
# predicted=3.170898, expected=3.150000
# predicted=3.151585, expected=3.020000
# predicted=3.065939, expected=3.380000
# predicted=3.241572, expected=3.170000
# predicted=3.220022, expected=3.360000
# predicted=3.310008, expected=3.360000
# predicted=3.356485, expected=3.760000
# predicted=3.615516, expected=3.440000
# predicted=3.554774, expected=3.470000
# predicted=3.510517, expected=3.590000
# predicted=3.554606, expected=3.580000
# predicted=3.575483, expected=3.570000
# predicted=3.577465, expected=3.670000
# predicted=3.636060, expected=3.360000
# predicted=3.478259, expected=3.190000
# predicted=3.281435, expected=3.220000
# predicted=3.204911, expected=3.180000
# predicted=3.163121, expected=3.140000
# predicted=3.132553, expected=2.980000
# predicted=3.028651, expected=3.260000
# predicted=3.148985, expected=3.040000
# predicted=3.094183, expected=2.970000
# predicted=3.014120, expected=3.250000
# predicted=3.143278, expected=3.110000
# predicted=3.138278, expected=2.840000
# predicted=2.961611, expected=2.950000
# predicted=2.928262, expected=2.640000
# predicted=2.737771, expected=2.740000
# predicted=2.703246, expected=2.830000
# predicted=2.761694, expected=2.690000
# predicted=2.720430, expected=2.640000
# predicted=2.665780, expected=2.820000
# predicted=2.748828, expected=2.880000
# predicted=2.837884, expected=2.640000
# predicted=2.735056, expected=2.620000
# predicted=2.655185, expected=2.830000
# predicted=2.745223, expected=2.900000
# predicted=2.847650, expected=2.680000
# predicted=2.764950, expected=2.380000
# predicted=2.524715, expected=2.630000
# predicted=2.548673, expected=2.360000
# predicted=2.422614, expected=2.470000
# predicted=2.427309, expected=2.420000
# predicted=2.414629, expected=2.470000
# predicted=2.443252, expected=2.590000
# predicted=2.535201, expected=2.560000
# predicted=2.565862, expected=2.690000
# predicted=2.652030, expected=2.490000
# predicted=2.571073, expected=2.420000
# predicted=2.472826, expected=2.740000
# predicted=2.617452, expected=2.320000
# predicted=2.452956, expected=2.200000
# predicted=2.279003, expected=2.410000
# predicted=2.323586, expected=2.290000
# predicted=2.297285, expected=2.480000
# predicted=2.402028, expected=2.560000
# predicted=2.512418, expected=2.580000
# predicted=2.576347, expected=2.810000
# predicted=2.737037, expected=2.530000
# predicted=2.643537, expected=2.860000
# predicted=2.772073, expected=2.300000
# predicted=2.504720, expected=2.420000
# predicted=2.417326, expected=2.230000
# predicted=2.276474, expected=2.500000
# predicted=2.380011, expected=2.490000
# predicted=2.451845, expected=2.210000
# predicted=2.318142, expected=2.540000
# predicted=2.436235, expected=2.210000
# predicted=2.311929, expected=2.050000
# predicted=2.137572, expected=2.840000
# predicted=2.529931, expected=2.560000
# predicted=2.599145, expected=2.620000
# predicted=2.641260, expected=2.770000
# predicted=2.736713, expected=3.180000
# predicted=3.027263, expected=3.370000
# predicted=3.290199, expected=3.730000
# predicted=3.620203, expected=3.660000
# predicted=3.720303, expected=3.850000
# predicted=3.843245, expected=4.260000
# predicted=4.133566, expected=4.150000
# predicted=4.203862, expected=4.360000
# predicted=4.332818, expected=4.650000
# predicted=4.559744, expected=4.110000
# predicted=4.335083, expected=4.270000
# predicted=4.277323, expected=4.440000
# predicted=4.360354, expected=4.570000
# predicted=4.495341, expected=4.040000
# predicted=4.243139, expected=4.120000
# predicted=4.136742, expected=4.020000
# predicted=4.036783, expected=4.010000
# predicted=3.993522, expected=4.010000
# predicted=3.986457, expected=3.690000
# predicted=3.798605, expected=3.820000
# predicted=3.778437, expected=3.820000
# predicted=3.787997, expected=3.690000
# predicted=3.724051, expected=3.480000
# predicted=3.563650, expected=3.720000
# predicted=3.628309, expected=3.840000
# predicted=3.756004, expected=3.830000
# predicted=3.821197, expected=4.230000
# predicted=4.088040, expected=4.240000
# predicted=4.230496, expected=4.620000
# predicted=4.509588, expected=3.890000
# predicted=4.193265, expected=4.450000
# predicted=4.320364, expected=3.910000
# predicted=4.080936, expected=3.980000
# predicted=3.983854, expected=4.130000
# predicted=4.043739, expected=4.170000
# predicted=4.119834, expected=4.120000
# predicted=4.132230, expected=3.680000
# predicted=3.864198, expected=3.720000
# predicted=3.735217, expected=3.640000
# predicted=3.641213, expected=3.370000
# predicted=3.447825, expected=3.280000
# predicted=3.303691, expected=3.290000
# predicted=3.256370, expected=3.190000
# predicted=3.193998, expected=3.280000
# predicted=3.228030, expected=3.270000
# predicted=3.252458, expected=3.260000
# predicted=3.260650, expected=3.490000
# predicted=3.402644, expected=3.560000
# predicted=3.522548, expected=3.330000
# predicted=3.434046, expected=3.800000
# predicted=3.652043, expected=3.390000
# predicted=3.527442, expected=3.430000
# predicted=3.460094, expected=3.640000
# predicted=3.555202, expected=3.590000
# predicted=3.586951, expected=3.580000
# predicted=3.591807, expected=3.530000
# predicted=3.558386, expected=3.570000
# predicted=3.561382, expected=3.410000
# predicted=3.468580, expected=3.900000
# predicted=3.714516, expected=3.670000
# predicted=3.722518, expected=3.360000
# predicted=3.516597, expected=3.870000
# predicted=3.701735, expected=3.210000
# predicted=3.424461, expected=3.350000
# predicted=3.340363, expected=3.590000
# predicted=3.463577, expected=3.530000
# predicted=3.514339, expected=3.260000
# predicted=3.372633, expected=3.400000
# predicted=3.370006, expected=3.450000
# predicted=3.411078, expected=3.120000
# predicted=3.239284, expected=3.090000
# predicted=3.121898, expected=3.140000
# predicted=3.103639, expected=3.130000
# predicted=3.106090, expected=3.270000
# predicted=3.200827, expected=2.770000
# predicted=2.954419, expected=2.760000
# predicted=2.800965, expected=2.600000
# predicted=2.640967, expected=2.640000
# predicted=2.600020, expected=2.610000
# predicted=2.584672, expected=2.550000
# predicted=2.553377, expected=2.560000
# predicted=2.548473, expected=2.580000
# predicted=2.563521, expected=2.400000
# predicted=2.465561, expected=2.690000
# predicted=2.585520, expected=2.460000
# predicted=2.523738, expected=2.560000
# predicted=2.540538, expected=2.210000
# predicted=2.341527, expected=2.360000
# predicted=2.319998, expected=2.190000
# predicted=2.225960, expected=2.210000
# predicted=2.195132, expected=2.200000
# predicted=2.185324, expected=2.280000
# predicted=2.236387, expected=2.250000
# predicted=2.250875, expected=2.170000
# predicted=2.206604, expected=1.990000
# predicted=2.069884, expected=2.050000
# predicted=2.033124, expected=2.120000
# predicted=2.070664, expected=1.990000
# predicted=2.022649, expected=1.900000
# predicted=1.940757, expected=2.070000
# predicted=2.002583, expected=2.070000
# predicted=2.047709, expected=2.060000
# predicted=2.064198, expected=1.710000
# predicted=1.855913, expected=1.700000
# predicted=1.729262, expected=1.820000
# predicted=1.751560, expected=1.840000
# predicted=1.796889, expected=1.800000
# predicted=1.803242, expected=2.130000
# predicted=2.003748, expected=2.180000
# predicted=2.144594, expected=2.210000
# predicted=2.219834, expected=2.270000
# predicted=2.275542, expected=2.580000
# predicted=2.478400, expected=2.490000
# predicted=2.525703, expected=2.570000
# predicted=2.574982, expected=2.660000
# predicted=2.642808, expected=2.460000
# predicted=2.549207, expected=2.730000
# predicted=2.649386, expected=2.720000
# predicted=2.705388, expected=2.510000
# predicted=2.601197, expected=2.830000
# predicted=2.727471, expected=2.800000
# predicted=2.787925, expected=2.830000
# predicted=2.829424, expected=2.870000
# predicted=2.866685, expected=3.340000
# predicted=3.164009, expected=3.390000
# predicted=3.354329, expected=4.250000
# predicted=3.949624, expected=4.170000
# predicted=4.202045, expected=3.920000
# predicted=4.114690, expected=4.260000
# predicted=4.219986, expected=3.850000
# predicted=4.017663, expected=3.850000
# predicted=3.890119, expected=4.010000
# predicted=3.932770, expected=4.000000
# predicted=3.969903, expected=3.930000
# predicted=3.950508, expected=3.450000
# predicted=3.644959, expected=3.630000
# predicted=3.584527, expected=3.560000
# predicted=3.541052, expected=3.830000
# predicted=3.699111, expected=3.630000
# predicted=3.677000, expected=3.330000
# predicted=3.469613, expected=3.230000
# predicted=3.291072, expected=3.390000
# predicted=3.309832, expected=2.920000
# predicted=3.060776, expected=3.460000
# predicted=3.257610, expected=3.360000
# predicted=3.335854, expected=2.890000
# predicted=3.083784, expected=2.720000
# predicted=2.828092, expected=2.640000
# predicted=2.659129, expected=2.610000
# predicted=2.581266, expected=2.480000
# predicted=2.489008, expected=2.710000
# predicted=2.597048, expected=2.380000
# predicted=2.472809, expected=3.040000
# predicted=2.800049, expected=2.700000
# predicted=2.786970, expected=2.320000
# predicted=2.518463, expected=2.200000
# predicted=2.286614, expected=2.110000
# predicted=2.127192, expected=2.050000
# predicted=2.034968, expected=2.010000
# predicted=1.987986, expected=1.930000
# predicted=1.933240, expected=1.910000
# predicted=1.902944, expected=1.670000
# predicted=1.750176, expected=1.700000
# predicted=1.690648, expected=1.750000
# predicted=1.706241, expected=1.740000
# predicted=1.721666, expected=1.790000
# predicted=1.763859, expected=1.740000
# predicted=1.756443, expected=1.990000
# predicted=1.899976, expected=2.000000
# predicted=1.984807, expected=2.000000
# predicted=2.016814, expected=2.280000
# predicted=2.190680, expected=2.210000
# predicted=2.235963, expected=2.490000
# predicted=2.410493, expected=2.310000
# ...
# predicted=3.793883, expected=4.320000
# predicted=4.107731, expected=3.850000
# predicted=3.991921, expected=3.830000
# predicted=3.887024, expected=3.850000
# predicted=3.845390, expected=3.810000
# predicted=3.809820, expected=3.410000
# predicted=3.548135, expected=4.370000
# predicted=4.016190, expected=3.640000
# predicted=3.842609, expected=4.450000
# predicted=4.214385, expected=4.240000
# predicted=4.291073, expected=3.850000
# predicted=4.048600, expected=3.610000
# predicted=3.744201, expected=3.810000
# predicted=3.724259, expected=4.100000
# predicted=3.935603, expected=3.960000
# predicted=3.977733, expected=3.530000
# predicted=3.713637, expected=3.330000
# predicted=3.435385, expected=3.030000
# predicted=3.122016, expected=3.110000
# predicted=3.042220, expected=2.980000
# predicted=2.964510, expected=2.950000
# predicted=2.928986, expected=2.710000
# predicted=2.776226, expected=2.760000
# predicted=2.735540, expected=2.730000
# predicted=2.714522, expected=2.700000
# predicted=2.695713, expected=2.710000
# predicted=2.698131, expected=2.750000
# predicted=2.728730, expected=2.890000
# predicted=2.834214, expected=2.680000
# predicted=2.756399, expected=2.880000
# predicted=2.827805, expected=2.790000
# predicted=2.813693, expected=2.830000
# predicted=2.824994, expected=3.010000
# predicted=2.943224, expected=2.960000
# predicted=2.974001, expected=2.940000
# predicted=2.964942, expected=3.090000
# predicted=3.046212, expected=3.140000
# predicted=3.119417, expected=3.060000
# predicted=3.099330, expected=3.010000
# predicted=3.046115, expected=3.280000
# predicted=3.184980, expected=2.830000
# predicted=2.982685, expected=3.010000
# predicted=2.973532, expected=3.050000
# predicted=3.010645, expected=2.570000
# predicted=2.736991, expected=2.680000
# predicted=2.656821, expected=2.780000
# predicted=2.705036, expected=2.830000
# predicted=2.781065, expected=2.730000
# predicted=2.760803, expected=2.810000
# predicted=2.792439, expected=2.680000
# predicted=2.727520, expected=2.740000
# predicted=2.726569, expected=2.700000
# predicted=2.706667, expected=2.910000
# predicted=2.829579, expected=2.840000
# predicted=2.854822, expected=2.740000
# predicted=2.793693, expected=2.810000
# predicted=2.797649, expected=2.890000
# predicted=2.853927, expected=2.720000
# predicted=2.778784, expected=2.710000
# predicted=2.726401, expected=2.890000
# predicted=2.816915, expected=3.280000
# predicted=3.117746, expected=2.940000
# predicted=3.059633, expected=3.090000
# predicted=3.088082, expected=3.160000
# predicted=3.141159, expected=2.690000
# predicted=2.870235, expected=2.980000
# predicted=2.898348, expected=2.680000
# predicted=2.751959, expected=2.830000
# predicted=2.773193, expected=2.740000
# predicted=2.746254, expected=2.740000
# predicted=2.735719, expected=2.680000
# predicted=2.696786, expected=2.800000
# predicted=2.753486, expected=2.430000
# predicted=2.557777, expected=2.650000
# predicted=2.585334, expected=2.590000
# predicted=2.582260, expected=2.750000
# predicted=2.684572, expected=2.560000
# predicted=2.622733, expected=2.570000
# predicted=2.585119, expected=2.220000
# predicted=2.348887, expected=2.310000
# predicted=2.282648, expected=2.640000
# predicted=2.480610, expected=2.410000
# predicted=2.460053, expected=2.500000
# predicted=2.489988, expected=2.460000
# predicted=2.477916, expected=2.240000
# predicted=2.329485, expected=2.600000
# predicted=2.474224, expected=2.410000
# predicted=2.449399, expected=2.530000
# predicted=2.501072, expected=2.330000
# predicted=2.403158, expected=2.500000
# predicted=2.450642, expected=2.380000
# predicted=2.409774, expected=2.240000
# predicted=2.298066, expected=2.220000
# predicted=2.228808, expected=2.120000
# predicted=2.142136, expected=2.270000
# predicted=2.201158, expected=2.090000
# predicted=2.134116, expected=2.040000
# predicted=2.065038, expected=2.250000
# predicted=2.165577, expected=2.320000
# predicted=2.273459, expected=2.390000
# predicted=2.368166, expected=2.810000
# predicted=2.667840, expected=2.910000
# predicted=2.877384, expected=3.110000
# predicted=3.078190, expected=3.300000
# predicted=3.269983, expected=3.900000
# predicted=3.716148, expected=3.990000
# predicted=3.980948, expected=3.760000
# predicted=3.919008, expected=3.870000
# predicted=3.905403, expected=3.900000
# predicted=3.905897, expected=4.080000
# predicted=4.016813, expected=4.030000
# predicted=4.043978, expected=4.190000
# predicted=4.146899, expected=4.140000
# predicted=4.163705, expected=3.810000
# predicted=3.952178, expected=3.820000
# predicted=3.837962, expected=3.450000
# predicted=3.564083, expected=3.920000
# predicted=3.731376, expected=4.030000
# predicted=3.926384, expected=3.930000
# predicted=3.963317, expected=4.040000
# predicted=4.030095, expected=4.130000
# predicted=4.110508, expected=3.820000
# predicted=3.947712, expected=3.840000
# predicted=3.860294, expected=4.200000
# predicted=4.052171, expected=4.050000
# predicted=4.074518, expected=3.940000
# predicted=4.002334, expected=4.150000
# predicted=4.087585, expected=4.420000
# predicted=4.307548, expected=3.990000
# predicted=4.148536, expected=4.040000
# predicted=4.068906, expected=3.600000
# predicted=3.757279, expected=3.850000
# predicted=3.758171, expected=3.620000
# predicted=3.650870, expected=3.350000
# predicted=3.436916, expected=3.370000
# predicted=3.350607, expected=3.330000
# predicted=3.307473, expected=3.420000
# predicted=3.360153, expected=4.030000
# predicted=3.783209, expected=3.560000
# predicted=3.713497, expected=3.090000
# predicted=3.335391, expected=3.340000
# predicted=3.282484, expected=3.390000
# predicted=3.321010, expected=3.330000
# predicted=3.322115, expected=3.330000
# predicted=3.325566, expected=3.460000
# predicted=3.409988, expected=3.400000
# predicted=3.417356, expected=3.310000
# predicted=3.356171, expected=3.610000
# predicted=3.507904, expected=3.340000
# predicted=3.424277, expected=3.610000
# predicted=3.535259, expected=3.330000
# predicted=3.422462, expected=3.350000
# predicted=3.364558, expected=3.140000
# predicted=3.209708, expected=3.220000
# predicted=3.185933, expected=3.270000
# predicted=3.223768, expected=2.840000
# predicted=2.983693, expected=2.880000
# predicted=2.879873, expected=2.580000
# predicted=2.660533, expected=2.990000
# predicted=2.820263, expected=2.980000
# predicted=2.929204, expected=2.850000
# predicted=2.900270, expected=2.860000
# predicted=2.877960, expected=2.910000
# predicted=2.895545, expected=2.960000
# predicted=2.937899, expected=2.760000
# predicted=2.833878, expected=2.810000
# predicted=2.804834, expected=3.010000
# predicted=2.923649, expected=2.950000
# predicted=2.955770, expected=2.920000
# predicted=2.944272, expected=2.940000
# predicted=2.943759, expected=2.720000
# predicted=2.804126, expected=2.800000
# predicted=2.779217, expected=3.090000
# predicted=2.961933, expected=2.690000
# predicted=2.816426, expected=2.640000
# predicted=2.691500, expected=2.760000
# predicted=2.709016, expected=2.370000
# predicted=2.489879, expected=2.400000
# predicted=2.395601, expected=2.510000
# predicted=2.438109, expected=2.420000
# predicted=2.422827, expected=2.350000
# predicted=2.373224, expected=2.340000
# predicted=2.342915, expected=2.180000
# predicted=2.232352, expected=2.470000
# predicted=2.360339, expected=2.600000
# predicted=2.523549, expected=2.350000
# predicted=2.445843, expected=2.360000
# predicted=2.391031, expected=2.630000
# predicted=2.531632, expected=2.570000
# predicted=2.574947, expected=2.320000
# predicted=2.429305, expected=2.210000
# predicted=2.273594, expected=2.180000
# predicted=2.183051, expected=2.090000
# predicted=2.098244, expected=2.360000
# predicted=2.238954, expected=2.320000
# predicted=2.303685, expected=2.220000
# predicted=2.266733, expected=2.150000
# predicted=2.193382, expected=2.210000
# predicted=2.192004, expected=2.130000
# predicted=2.148483, expected=1.920000
# predicted=1.996465, expected=1.870000
# predicted=1.889469, expected=1.860000
# predicted=1.843480, expected=1.710000
# predicted=1.742064, expected=1.660000
# predicted=1.667674, expected=1.660000
# predicted=1.642353, expected=1.700000
# predicted=1.666800, expected=1.630000
# predicted=1.643250, expected=1.530000
# predicted=1.568231, expected=1.770000
# predicted=1.681276, expected=1.530000
# predicted=1.599513, expected=1.650000
# predicted=1.622925, expected=1.890000
# predicted=1.791110, expected=2.070000
# predicted=1.993414, expected=1.930000
# predicted=1.996287, expected=1.830000
# predicted=1.908330, expected=1.860000
# predicted=1.870073, expected=1.880000
# predicted=1.867211, expected=1.890000
# predicted=1.877648, expected=1.970000
# predicted=1.935819, expected=1.980000
# predicted=1.972934, expected=2.250000
# predicted=2.156289, expected=2.340000
# predicted=2.304558, expected=2.310000
# predicted=2.344033, expected=2.600000
# predicted=2.524643, expected=2.730000
# predicted=2.690108, expected=2.780000
# predicted=2.786836, expected=2.680000
# predicted=2.750318, expected=3.000000
# predicted=2.912885, expected=3.010000
# predicted=3.002151, expected=3.500000
# predicted=3.340100, expected=3.350000
# predicted=3.409965, expected=2.950000
# predicted=3.156060, expected=3.290000
# predicted=3.213330, expected=3.080000
# predicted=3.128308, expected=3.160000
# predicted=3.134196, expected=2.920000
# predicted=2.995312, expected=2.780000
# predicted=2.836163, expected=2.720000
# predicted=2.728613, expected=2.510000
# predicted=2.560877, expected=2.230000
# predicted=2.314314, expected=2.140000
# predicted=2.150393, expected=2.160000
# predicted=2.109475, expected=2.060000
# predicted=2.053847, expected=2.000000
# predicted=2.001666, expected=1.960000
# predicted=1.960081, expected=1.840000
# predicted=1.871975, expected=1.970000
# predicted=1.914698, expected=1.680000
# predicted=1.766703, expected=1.630000
# predicted=1.656812, expected=1.670000
# predicted=1.638317, expected=1.770000
# predicted=1.707899, expected=1.840000
# predicted=1.797066, expected=1.740000
# predicted=1.777758, expected=1.720000
# predicted=1.744711, expected=1.720000
# predicted=1.725149, expected=1.860000
# predicted=1.805297, expected=1.790000
# predicted=1.806698, expected=1.850000
# predicted=1.838400, expected=1.750000
# predicted=1.789589, expected=1.830000
# predicted=1.809810, expected=1.980000
# predicted=1.918093, expected=1.890000
# predicted=1.918216, expected=2.070000
# predicted=2.020557, expected=2.100000
# predicted=2.089557, expected=2.160000
# predicted=2.152235, expected=2.370000
# predicted=2.306350, expected=2.350000
# predicted=2.365089, expected=2.560000
# predicted=2.509226, expected=2.550000
# predicted=2.566267, expected=2.870000
# predicted=2.778750, expected=2.590000
# predicted=2.702244, expected=2.640000
# predicted=2.667096, expected=2.880000
# predicted=2.797018, expected=2.810000
# predicted=2.824446, expected=2.490000
# predicted=2.625941, expected=2.450000
# predicted=2.487974, expected=2.920000
# predicted=2.727170, expected=2.710000
# predicted=2.741915, expected=2.700000
# predicted=2.727833, expected=2.570000
# predicted=2.631087, expected=2.580000
# predicted=2.584524, expected=2.760000
# predicted=2.681822, expected=2.660000
# predicted=2.678522, expected=2.830000
# predicted=2.777311, expected=2.620000
# predicted=2.695539, expected=3.000000
# predicted=2.880526, expected=2.990000
# predicted=2.976435, expected=3.470000
# predicted=3.312757, expected=3.150000
# predicted=3.274252, expected=2.830000
# predicted=3.013332, expected=3.250000
# predicted=3.128101, expected=3.220000
# predicted=3.190792, expected=3.200000
# predicted=3.208427, expected=3.120000
# predicted=3.160310, expected=2.860000
# predicted=2.966838, expected=2.620000
# predicted=2.716102, expected=2.770000
# predicted=2.697519, expected=2.800000
# predicted=2.738392, expected=2.730000
# predicted=2.730243, expected=2.590000
# predicted=2.639551, expected=2.670000
# predicted=2.643417, expected=2.780000
# predicted=2.723884, expected=2.600000
# predicted=2.656550, expected=2.470000
# predicted=2.532754, expected=2.810000
# predicted=2.684955, expected=2.370000
# predicted=2.502376, expected=2.610000
# predicted=2.547093, expected=2.840000
# predicted=2.729195, expected=2.580000
# predicted=2.663600, expected=2.590000
# predicted=2.618034, expected=2.540000
# predicted=2.562056, expected=2.630000
# predicted=2.593135, expected=2.990000
# predicted=2.842845, expected=2.430000
# predicted=2.623324, expected=2.690000
# predicted=2.646043, expected=2.390000
# predicted=2.481425, expected=2.870000
# predicted=2.697420, expected=2.880000
# predicted=2.835381, expected=2.830000
# predicted=2.863064, expected=2.590000
# predicted=2.708331, expected=3.130000
# predicted=2.954817, expected=3.060000
# predicted=3.052793, expected=2.840000
# predicted=2.947556, expected=3.260000
# predicted=3.137823, expected=3.200000
# predicted=3.204845, expected=3.300000
# predicted=3.286229, expected=3.490000
# predicted=3.435524, expected=3.090000
# predicted=3.251236, expected=3.300000
# predicted=3.265214, expected=3.510000
# predicted=3.414301, expected=3.650000
# predicted=3.583979, expected=3.480000
# predicted=3.554388, expected=3.380000
# predicted=3.454581, expected=3.440000
# predicted=3.433470, expected=3.370000
# predicted=3.385566, expected=3.410000
# predicted=3.390069, expected=3.200000
# predicted=3.267353, expected=2.990000
# predicted=3.072632, expected=2.870000
# predicted=2.906400, expected=2.840000
# predicted=2.822816, expected=2.740000
# predicted=2.740864, expected=2.710000
# predicted=2.696550, expected=2.740000
# predicted=2.706838, expected=2.690000
# predicted=2.691119, expected=2.510000
# predicted=2.572921, expected=2.580000
# predicted=2.556849, expected=2.420000
# predicted=2.460244, expected=2.400000
# predicted=2.402852, expected=2.380000
# predicted=2.371578, expected=2.310000
# predicted=2.321205, expected=2.370000
# predicted=2.339138, expected=2.560000
# predicted=2.475459, expected=2.430000
# predicted=2.467609, expected=2.110000
# predicted=2.250266, expected=2.110000
# predicted=2.130843, expected=2.020000
# predicted=2.029798, expected=2.070000
# predicted=2.026456, expected=2.130000
# predicted=2.079424, expected=1.890000
# predicted=1.963969, expected=2.010000
# predicted=1.976095, expected=1.980000
# predicted=1.973685, expected=1.910000
# predicted=1.931379, expected=1.760000
# predicted=1.816218, expected=1.870000
# predicted=1.828779, expected=1.750000
# predicted=1.772753, expected=1.570000
# predicted=1.634021, expected=1.770000
# predicted=1.692873, expected=1.780000
# predicted=1.746126, expected=1.800000
# predicted=1.787740, expected=1.700000
# predicted=1.742369, expected=1.620000
# predicted=1.662359, expected=1.750000
# predicted=1.703484, expected=1.750000
# predicted=1.733523, expected=1.640000
# predicted=1.679902, expected=1.700000
# predicted=1.686135, expected=1.660000
# predicted=1.668134, expected=1.510000
# predicted=1.565427, expected=1.520000
# predicted=1.519365, expected=1.610000
# predicted=1.561902, expected=1.690000
# predicted=1.643165, expected=1.520000
# predicted=1.578971, expected=1.600000
# predicted=1.587409, expected=1.630000
# predicted=1.613527, expected=1.810000
# predicted=1.740669, expected=1.540000
# predicted=1.636307, expected=1.480000
# predicted=1.530561, expected=1.650000
# predicted=1.585813, expected=1.530000
# predicted=1.551471, expected=1.500000
# predicted=1.514069, expected=1.500000
# predicted=1.497295, expected=1.420000
# predicted=1.442945, expected=1.360000
# predicted=1.379998, expected=1.460000
# predicted=1.415877, expected=1.410000
# predicted=1.412011, expected=1.380000
# predicted=1.391248, expected=1.220000
# predicted=1.280280, expected=1.270000
# predicted=1.254978, expected=1.340000
# predicted=1.296695, expected=1.310000
# predicted=1.306861, expected=1.210000
# predicted=1.248422, expected=1.310000
# predicted=1.278836, expected=1.270000
# predicted=1.274723, expected=1.140000
# predicted=1.190142, expected=1.240000
# predicted=1.208124, expected=1.210000
# predicted=1.206717, expected=1.240000
# predicted=1.226325, expected=1.270000
# predicted=1.256283, expected=1.410000
# predicted=1.358459, expected=1.370000
# predicted=1.384065, expected=1.480000
# predicted=1.455735, expected=1.420000
# predicted=1.449226, expected=1.530000
# predicted=1.505342, expected=1.450000
# predicted=1.481640, expected=1.540000
# predicted=1.519003, expected=1.450000
# predicted=1.481888, expected=1.430000
# predicted=1.446013, expected=1.390000
# predicted=1.403889, expected=1.540000
# predicted=1.479822, expected=1.600000
# predicted=1.563311, expected=1.530000
# predicted=1.558796, expected=1.590000

# %% [markdown]
# ## Visualization
#
# After the model completes its forecast, create a plot to visualize the difference between the predicted values and expected vales for wave heights.

# %%
test_x = arima_test.index # creating an index variable so that it's the dates

plt.figure (figsize=(12,10)) # setting up the plot size

plt.plot(test_x, arima_test, label='Expected') # plotting expected values
plt.plot(test_x, predictions, color='red', label='Prediction') # plotting predicted values
plt.xlabel('Date')
plt.ylabel('Wave Height')
plt.title('Difference Between Predicted and Actual Wave Heights')
plt.legend() # adding a legend to the plot

plt.xticks(rotation=45) # rotating the x labels for better visualization

plt.show()

# %% [markdown]
# ## Model Evaluation
#
# In machine learning, there are different ways to evaluate how well your model performed depending on what type of model you use.
#
# For this project, we'll use mean absolute error and root squared value to determine how well our model did.
#
# You can review this [resource](https://www.analyticsvidhya.com/blog/2021/10/evaluation-metric-for-regression-models/) to understand the metrics better.

# %%
mae = mean_absolute_error(arima_test, predictions) # calculating mean absolute error
r_sq = r2_score(arima_test, predictions) # calculating root squared value
print('Test MAE: ', mae)
print('Test R^2: ', r_sq)
# Out:
# Test MAE:  0.1543645059115598
# Test R^2:  0.9478662266840074

# %% [markdown]
# Based on these results and the visualization, this model did pretty good!

# %% [markdown]
# ## Forecasting Values for the Future
#
# Now that we've fitted, trained, tested, and evaluated our model, let's try to forecast future values.
#
# Resource:
# https://www.analyticsvidhya.com/blog/2020/10/how-to-create-an-arima-model-for-time-series-forecasting-in-python/

# %%
# Extending the model to predict future values beyond the test set
future_predictions = list()
future_periods = 144  # Number of future periods to forecast, e.g., 144 intervals for 24 hours if each interval is 10 minutes
# Using the model to predict future values
for t in range(future_periods):
    model = ARIMA(history, order=(1, 1, 2))  # Adjust the order parameters as needed
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    future_predictions.append(yhat)
    history.append(yhat)  # Append the predicted value to history for the next prediction
# Creating future dates for the predictions
last_date = arima_data.index[-1]
future_dates = [last_date + pd.DateOffset(minutes=10 * (t + 1)) for t in range(future_periods)]
# Creating a DataFrame for the future predictions
future_df = pd.DataFrame(data=future_predictions, index=future_dates, columns=['forecast'])
# Plotting the results
import matplotlib.pyplot as plt
# Combining the original data with the future predictions for plotting
combined_df = pd.concat([arima_data, future_df])
plt.figure(figsize=(12, 8))
plt.plot(combined_df.index, combined_df['WVHT'], label='Observed')
plt.plot(future_df.index, future_df['forecast'], label='Forecast', linestyle='--')
plt.legend()
plt.show()

# %%
model_fit.save('file')

# %%
from statsmodels.tsa.arima.model import ARIMAResults

results_ = ARIMAResults.load('file')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-f1db91d93d6a> in <cell line: 3>()
#       1 from statsmodels.tsa.arima.model import ARIMAResults
#       2
# ----> 3 results_ = ARIMAResults.load('file')
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py in load(cls, fname)
#    2287
#    2288         from statsmodels.iolib.smpickle import load_pickle
# -> 2289         return load_pickle(fname)
#    2290
#    2291     def remove_data(self):
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/iolib/smpickle.py in load_pickle(fname)
#      39     import pickle
#      40
# ---> 41     with get_file_obj(fname, "rb") as fin:
#      42         return pickle.load(fin)
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/iolib/openfile.py in get_file_obj(fname, mode, encoding)
#      63         fname = Path(fname)
#      64     if isinstance(fname, Path):
# ---> 65         return fname.open(mode=mode, encoding=encoding)
#      66     elif hasattr(fname, "open"):
#      67         return fname.open(mode=mode, encoding=encoding)
#
# /usr/lib/python3.10/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1117         if "b" not in mode:
#    1118             encoding = io.text_encoding(encoding)
# -> 1119         return self._accessor.open(self, mode, buffering, encoding, errors,
#    1120                                    newline)
#    1121
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file'

# %% [markdown]
# ## Exploring Trends in Seasonality

# %%
arima_data['WVHT'] = arima_data['WVHT'].astype(float) # changing the datatype for WVHT for a nicer look on the plot
plt.figure(figsize=(10,6)) # setting up the dimentions for our plot
plt.title('2017 Wave Height Measurements (m) for Kauai Island Station 51101') # setting up a title
plt.plot(arima_data['WVHT']) # plotting our data

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(arima_data, model = 'additive', period = 840)

decomposition.plot()
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
plt.figure(figsize=(16, 10))
decomposition = seasonal_decompose(arima_data, model = 'multiplicative', period = 840)

decomposition.plot()
plt.show()

# %% [markdown]
# #Connecting to Git
